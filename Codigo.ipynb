# %%
#pip install Flask SQLAlchemy fastavro

# %%
#pip install --upgrade SQLAlchemy

# %%
#from flask import Flask, request, jsonify
from flask import Flask, render_template, request, jsonify, send_file
from sqlalchemy import create_engine, MetaData, Table, Column, Integer, String, DateTime
from sqlalchemy.orm import sessionmaker
from sqlalchemy.exc import IntegrityError, SQLAlchemyError
from sqlalchemy import text, inspect
import csv
import os
import datetime
import traceback
import fastavro

# %%
# Initialize SQLAlchemy engine
engine = create_engine('sqlite:///database.db', echo=False)
meta = MetaData()
Session = sessionmaker(bind=engine)
session = Session()

# Define database tables
employees = Table(
    'employees', meta,
    Column('id', Integer, primary_key=True),
    Column('name', String),
    Column('datetime', DateTime),
    Column('department_id', Integer),
    Column('job_id', Integer)
)

departments = Table(
    'departments', meta,
    Column('id', Integer, primary_key=True),
    Column('department', String)
)

jobs = Table(
    'jobs', meta,
    Column('id', Integer, primary_key=True),
    Column('job', String)
)

# Drop existing tables and create new ones
meta.drop_all(engine, checkfirst=True)
meta.create_all(engine)

# %%
## Migrate initial Data
# Paths to CSV files
csv_files = {
    'hired_employees': ['id', 'name', 'datetime', 'department_id', 'job_id'],
    'departments': ['id', 'department'],
    'jobs': ['id', 'job']
}

# Function to parse datetime string into datetime object
def parse_datetime(datetime_str):
    return datetime.datetime.strptime(datetime_str, '%Y-%m-%dT%H:%M:%SZ')

# Function to read CSV files and insert data into the database
def migrate_data():
    for file, schema in csv_files.items():
        with open(file + '.csv', 'r') as csv_file:
            reader = csv.reader(csv_file)
            table_name = file
            table = None
            if table_name == 'hired_employees':
                table = employees
            elif table_name == 'departments':
                table = departments
            elif table_name == 'jobs':
                table = jobs
            if table is not None:  # Check if table exists

                # Parse datetime string if 'datetime' column exists in schema
                if 'datetime' in schema:
                    datetime_index = schema.index('datetime')
                    
                for row in reader:

                    # Validate row against schema format
                    if len(row) != len(schema):
                        print(f"Ignoring row ({table_name}): {row}. Number of columns doesn't match schema.")
                        continue
                        
                    # Convert hire_datetime string to datetime object
                    if 'datetime' in schema:
                        try:
                            row[datetime_index] = parse_datetime(row[datetime_index])
                        except ValueError:
                            print(f"Ignoring row ({table_name}): {row}. Invalid datetime format.")
                            continue

                    # Validate numeric fields
                    for index, value in enumerate(row):
                        if schema[index] in ['id', 'department_id', 'job_id']:  # Skip numeric fields that should be integers
                            try:
                                row[index] = float(value)  # Attempt to convert to float and update value in row
                            except ValueError:
                                print(f"Ignoring row ({table_name}): {row}. Non-numeric value found in field '{schema[index]}'.")
                                break  # Skip inserting this row
                    else:
                        # All validations passed, insert row into database
                        data = {column: value for column, value in zip(schema, row)}
                        session.execute(table.insert().values(**data))

                session.commit()

# Migrate data on application startup
migrate_data()
# Out:
# Ignoring row (hired_employees): [2.0, 'Ty Hofer', datetime.datetime(2021, 5, 30, 5, 43, 46), 8.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): [67.0, 'Thia Morican', datetime.datetime(2021, 3, 10, 19, 27, 10), '', '104']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [84.0, 'Ludvig Norwood', datetime.datetime(2021, 2, 26, 18, 47, 53), 3.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): [87.0, 'Cirstoforo Martinetto', datetime.datetime(2021, 10, 15, 9, 19, 20), '', '84']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [97.0, 'Beltran Natte', datetime.datetime(2021, 11, 1, 5, 12, 1), '', '67']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [133.0, 'Jennine Wapol', datetime.datetime(2022, 1, 24, 14, 45, 57), '', '49']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): ['157', 'Kellia Barribal', '', '4', '61']. Invalid datetime format.
# Ignoring row (hired_employees): [198.0, 'Carline Fryman', datetime.datetime(2021, 5, 29, 0, 23, 2), 5.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): [207.0, 'Ahmad Fader', datetime.datetime(2021, 5, 3, 4, 57, 25), '', '66']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [216.0, 'Theobald Tzarkov', datetime.datetime(2022, 1, 26, 14, 56, 48), '', '87']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [393.0, 'Bogey Hanwell', datetime.datetime(2022, 1, 5, 17, 29, 34), 6.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): [533.0, 'Tiertza Vanyashin', datetime.datetime(2022, 2, 4, 20, 16, 6), 3.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): ['663', 'Catha Gowrie', '', '4', '85']. Invalid datetime format.
# Ignoring row (hired_employees): [685.0, 'Bruno Pales', datetime.datetime(2022, 1, 16, 19, 23, 39), '', '92']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [758.0, 'Dyanne Rainy', datetime.datetime(2021, 6, 11, 0, 56, 42), 8.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): ['789', 'Jennine Fakeley', '', '2', '94']. Invalid datetime format.
# Ignoring row (hired_employees): [792.0, 'Hetty Cawthery', datetime.datetime(2022, 1, 21, 11, 8, 4), 10.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): [824.0, 'Kaitlynn Rannald', datetime.datetime(2021, 4, 18, 15, 11, 19), '', '64']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [832.0, 'Letta Paull', datetime.datetime(2021, 10, 29, 2, 35, 2), '', '122']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [932.0, 'Celeste Stops', datetime.datetime(2021, 2, 7, 22, 14, 1), 8.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): [942.0, 'Joaquin Kamenar', datetime.datetime(2021, 11, 29, 11, 54, 5), '', '64']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [955.0, 'Shena Gore', datetime.datetime(2021, 8, 16, 21, 25, 8), 9.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): [961.0, 'Lionello Andriesse', datetime.datetime(2022, 2, 12, 5, 19, 44), 8.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): ['1092', 'Floria Bineham', '', '7', '137']. Invalid datetime format.
# Ignoring row (hired_employees): ['1095', 'Lowell Blaber', '', '9', '141']. Invalid datetime format.
# Ignoring row (hired_employees): [1098.0, 'Colman Bleesing', datetime.datetime(2021, 10, 12, 17, 55, 32), '', '77']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [1110.0, 'Renee Bowe', datetime.datetime(2021, 8, 31, 20, 26, 32), '', '112']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): ['1252', 'Merrily Di Biaggi', '', '7', '19']. Invalid datetime format.
# Ignoring row (hired_employees): [1279.0, 'Phaidra Dubbin', datetime.datetime(2021, 10, 25, 12, 19, 32), '', '38']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [1304.0, 'Tildie Elby', datetime.datetime(2021, 9, 29, 14, 2, 27), 8.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): ['1323', 'Erv Fazan', '', '8', '34']. Invalid datetime format.
# Ignoring row (hired_employees): [1413.0, 'Berna Grigorkin', datetime.datetime(2021, 8, 2, 13, 21, 7), '', '103']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [1423.0, 'Rozelle Hadleigh', datetime.datetime(2021, 8, 8, 1, 23, 27), '', '108']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [1432.0, 'Jerrine Hammerson', datetime.datetime(2022, 1, 20, 22, 47, 27), '', '98']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [1463.0, 'Shell Houdhury', datetime.datetime(2022, 1, 4, 17, 20, 18), '', '50']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): ['1467', 'Sully Huc', '', '8', '148']. Invalid datetime format.
# Ignoring row (hired_employees): [1474.0, 'Calhoun Iacovolo', datetime.datetime(2021, 3, 6, 3, 2, 20), 7.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): ['1483', 'Paco Ivain', '', '5', '41']. Invalid datetime format.
# Ignoring row (hired_employees): [1523.0, 'Darelle Kenaway', datetime.datetime(2021, 5, 8, 10, 51, 7), 7.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): [1561.0, 'Saxon Lehmann', datetime.datetime(2021, 10, 28, 18, 29, 31), 3.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): [1589.0, 'Emmeline MacGrath', datetime.datetime(2021, 12, 12, 4, 57, 39), 11.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): [1590.0, 'Niven Mackrell', datetime.datetime(2021, 5, 17, 7, 18, 48), '', '85']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): [1613.0, 'Sigrid Matysik', datetime.datetime(2022, 2, 15, 21, 20, 1), '', '143']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): ['1686', 'Bessy Oakeby', '', '4', '53']. Invalid datetime format.
# Ignoring row (hired_employees): [1714.0, 'Mala Pales', datetime.datetime(2021, 5, 4, 4, 52, 48), '', '70']. Non-numeric value found in field 'department_id'.
# Ignoring row (hired_employees): ['1780', 'Annabelle Reilly', '', '6', '46']. Invalid datetime format.
# Ignoring row (hired_employees): ['1814', 'Theodore Sammut', '', '6', '86']. Invalid datetime format.
# Ignoring row (hired_employees): [1860.0, 'Marin Slipper', datetime.datetime(2022, 2, 8, 10, 39, 2), 4.0, '']. Non-numeric value found in field 'job_id'.
# Ignoring row (hired_employees): ['1869', 'Cesaro Solomon', '', '6', '66']. Invalid datetime format.
# Ignoring row (hired_employees): ['1925', 'Cary Tothe', '', '3', '104']. Invalid datetime format.
# Ignoring row (hired_employees): [1987.0, 'Shaina Wyldish', datetime.datetime(2021, 12, 13, 10, 5, 9), '', '102']. Non-numeric value found in field 'department_id'.

# %%
# Test loaded data with SQL
sql_query = text("SELECT * FROM employees")
result = session.execute(sql_query)
resultados = result.fetchall()

# Print the rows
print("\nHired Employees:")
for r in resultados:
    print(f"ID: {r.id}, Name: {r.name}")
# Out:
# Hired Employees:
# ID: 1, Name: Harold Vogt
# ID: 3, Name: Lyman Hadye
# ID: 4, Name: Lotti Crowthe
# ID: 5, Name: Gretna Lording
# ID: 6, Name: Marlow Antecki
# ID: 7, Name: Joan Rillett
# ID: 8, Name: Ulrick Nucciotti
# ID: 9, Name: Lucretia Northcote
# ID: 10, Name: Arty Giacobo
# ID: 11, Name: Libbi Dowtry
# ID: 12, Name: Jacky Oldred
# ID: 13, Name: Raine Mowett
# ID: 14, Name: Melonie Slocomb
# ID: 15, Name: Robers Swinden
# ID: 16, Name: Bone Serridge
# ID: 17, Name: Andee Tillot
# ID: 18, Name: Gay Philbin
# ID: 19, Name: Loralie Dundin
# ID: 20, Name: Tobi Lawton
# ID: 21, Name: Mandel Nayer
# ID: 22, Name: Toddy Gare
# ID: 23, Name: Jeremias Goudy
# ID: 24, Name: Lemar Aronsohn
# ID: 25, Name: Tanner Jopling
# ID: 26, Name: Bartolomeo Fetherstone
# ID: 27, Name: Elvina Bycraft
# ID: 28, Name: Letitia Bastin
# ID: 29, Name: Warner Astbury
# ID: 30, Name: Geri Pennings
# ID: 31, Name: Jerald Gilder
# ID: 32, Name: Wilt Di Francesco
# ID: 33, Name: Aldwin Hellmore
# ID: 34, Name: Corena Heritege
# ID: 35, Name: Malchy Pontain
# ID: 36, Name: Gasparo Ofen
# ID: 37, Name: Nikkie Whinray
# ID: 38, Name: Louisa Binion
# ID: 39, Name: Brook Tant
# ID: 40, Name: Cly Butt
# ID: 41, Name: Jena Iacomi
# ID: 42, Name: Pail Syne
# ID: 43, Name: Agneta Rae
# ID: 44, Name: Lanae Pedrozzi
# ID: 45, Name: Gipsy Cabrera
# ID: 46, Name: Philly Beecraft
# ID: 47, Name: Jimmie Jack
# ID: 48, Name: Lonee Hegden
# ID: 49, Name: Annecorinne Verny
# ID: 50, Name: Marybelle Henrichsen
# ID: 51, Name: Moe Kender
# ID: 52, Name: Trudie Arboin
# ID: 53, Name: Rebbecca Bazely
# ID: 54, Name: Bevin Battlestone
# ID: 55, Name: Marielle Nasi
# ID: 56, Name: Orelie Gauvin
# ID: 57, Name: Meggie Dulwitch
# ID: 58, Name: Elia D'Enrico
# ID: 59, Name: Sharron Stammirs
# ID: 60, Name: Washington Schleswig-Holstein
# ID: 61, Name: Artemus Featherby
# ID: 62, Name: Lou Hurd
# ID: 63, Name: Tanhya Ort
# ID: 64, Name: Florella Haquin
# ID: 65, Name: Saundra Franzini
# ID: 66, Name: Redford Rilton
# ID: 68, Name: Perceval MacLice
# ID: 69, Name: Sidoney Ciobutaru
# ID: 70, Name: Ted Dungay
# ID: 71, Name: Brandea Sinott
# ID: 72, Name: Judy Chifney
# ID: 73, Name: Matthus Szymanzyk
# ID: 74, Name: Wilma Duplain
# ID: 75, Name: Xylia Furlow
# ID: 76, Name: Carver Kirman
# ID: 77, Name: Fayette Prati
# ID: 78, Name: Christalle Constantine
# ID: 79, Name: Ashley Dickey
# ID: 80, Name: Angelika Stock
# ID: 81, Name: Caril Bewsey
# ID: 82, Name: Lief Bridgeman
# ID: 83, Name: Barth Bere
# ID: 85, Name: Dev Ingleson
# ID: 86, Name: Vinnie Andri
# ID: 88, Name: Rosabelle Sterzaker
# ID: 89, Name: Rodrique Fearnehough
# ID: 90, Name: Germana Bote
# ID: 91, Name: Rolf Tythacott
# ID: 92, Name: Floria Peniello
# ID: 93, Name: Belinda Savaage
# ID: 94, Name: Zachariah Comberbach
# ID: 95, Name: Lowell Woollin
# ID: 96, Name: Creight Rutter
# ID: 98, Name: Colman Casale
# ID: 99, Name: Marlo Tott
# ID: 100, Name: Karita Kettlestringes
# ID: 101, Name: Jenn Fumagallo
# ID: 102, Name: Ogden Ough
# ID: 103, Name: Cathy Blundin
# ID: 104, Name: Wenda Kaes
# ID: 105, Name: Jewelle Mathis
# ID: 106, Name: Jasper Matterdace
# ID: 107, Name: Welby Crocumbe
# ID: 108, Name: Marlie Gannicott
# ID: 109, Name: Bethanne Hurlin
# ID: 110, Name: Renee Bridie
# ID: 111, Name: Zsazsa Pash
# ID: 112, Name: Brett Griffey
# ID: 113, Name: Carlee Joyce
# ID: 114, Name: Grady Conman
# ID: 115, Name: Wilbert Cluer
# ID: 116, Name: Ardys Pirozzi
# ID: 117, Name: Putnem Lippiello
# ID: 118, Name: Blondell Pybus
# ID: 119, Name: Lucky Hadkins
# ID: 120, Name: Brietta Gillmore
# ID: 121, Name: Cristy Sockell
# ID: 122, Name: Gnni Gudgin
# ID: 123, Name: Alisha Headings
# ID: 124, Name: Merrill Symons
# ID: 125, Name: Gerri Baton
# ID: 126, Name: Olly Tully
# ID: 127, Name: Corinne Woofinden
# ID: 128, Name: Reuven Chatto
# ID: 129, Name: Stephana Gawthrop
# ID: 130, Name: Ferris Hammerberger
# ID: 131, Name: Angie McMurray
# ID: 132, Name: Gypsy Baselio
# ID: 134, Name: Lacee O'Hingerty
# ID: 135, Name: Foster Hobbing
# ID: 136, Name: Meryl Kew
# ID: 137, Name: Ichabod Maloney
# ID: 138, Name: Conrad Stoad
# ID: 139, Name: Celina Caris
# ID: 140, Name: Putnam Dodd
# ID: 141, Name: Marylin Brommage
# ID: 142, Name: Reginald Folca
# ID: 143, Name: Elston Millam
# ID: 144, Name: Angel Andrzejczak
# ID: 145, Name: Gretel Chittenden
# ID: 146, Name: Deirdre Hiley
# ID: 147, Name: Gaston Rayne
# ID: 148, Name: Rourke Inchbald
# ID: 149, Name: Katlin Haxby
# ID: 150, Name: Valentia Kellegher
# ID: 151, Name: Jarrett Oluwatoyin
# ID: 152, Name: Kori Foxton
# ID: 153, Name: Truman Garriock
# ID: 154, Name: Lurette Erwin
# ID: 155, Name: Jewel Valeri
# ID: 156, Name: Mikel Searby
# ID: 158, Name: Rube Dockerty
# ID: 159, Name: Gayleen Beslier
# ID: 160, Name: Sher Nolleau
# ID: 161, Name: Nobe Mackrell
# ID: 162, Name:
# ID: 163, Name: Nerta Cutteridge
# ID: 164, Name: Geraldine Playden
# ID: 165, Name: Charleen Billin
# ID: 166, Name: Hollis Goves
# ID: 167, Name: Alexis Jamson
# ID: 168, Name: Toinette Sammut
# ID: 169, Name: Dannye Juszczak
# ID: 170, Name: Kimberlyn Coule
# ID: 171, Name: Charis Muzzini
# ID: 172, Name: Roselle Leate
# ID: 173, Name: Myra Corington
# ID: 174, Name: Anetta Freeborn
# ID: 175, Name: Billy Odams
# ID: 176, Name: Barbie Alabaster
# ID: 177, Name: Ardella Schwartz
# ID: 178, Name: Petronilla Ashpital
# ID: 179, Name: Wolfy Leicester
# ID: 180, Name: Siobhan Backen
# ID: 181, Name: Joeann Chowne
# ID: 182, Name: Renell Iacovelli
# ID: 183, Name: Peyton Yaus
# ID: 184, Name: Alanson Dunne
# ID: 185, Name: Ryley Ruit
# ID: 186, Name: Claudelle Peele
# ID: 187, Name: Janna Forsey
# ID: 188, Name: Regen Presswell
# ID: 189, Name: Donny Ortiga
# ID: 190, Name: Amalia Vinall
# ID: 191, Name: Caldwell Dunniom
# ID: 192, Name: Olia Kleinhaus
# ID: 193, Name: Sarita Lemmertz
# ID: 194, Name: Lonny Duggan
# ID: 195, Name: Jordain Reardon
# ID: 196, Name: Harriot Kenaway
# ID: 197, Name: Mellie Dilrew
# ID: 199, Name: Fields Huby
# ID: 200, Name: Erick Grundey
# ID: 201, Name: Brien Richardin
# ID: 202, Name: Irving Saenz
# ID: 203, Name: Kienan Kinghorne
# ID: 204, Name: Dana Elby
# ID: 205, Name: Phillis Burgot
# ID: 206, Name: Osbourne Bernadot
# ID: 208, Name: Rasia Dimitriev
# ID: 209, Name: Tova Ostridge
# ID: 210, Name: Babita Grigorkin
# ID: 211, Name: Berny Daber
# ID: 212, Name: Alan Barhims
# ID: 213, Name: Brody Bothen
# ID: 214, Name: Hermann Brisson
# ID: 215, Name: Ewart Temblett
# ID: 217, Name: Marleen Huc
# ID: 218, Name: Stephie McCudden
# ID: 219, Name: Malorie Broggini
# ID: 220, Name: Aile Greatham
# ID: 221, Name: Valentia McFee
# ID: 222, Name: Blakelee Jell
# ID: 223, Name: Malvina Camelli
# ID: 224, Name: Hirsch Jeffrey
# ID: 225, Name: Barnabas Cockell
# ID: 226, Name: Hedy De Gregoli
# ID: 227, Name: Jeramey Pyson
# ID: 228, Name: Jobi Muncie
# ID: 229, Name: Luke Nickols
# ID: 230, Name: Arley Stroton
# ID: 231, Name: Daisie Branchet
# ID: 232, Name: Zach Gallelli
# ID: 233, Name: Tony Hayball
# ID: 234, Name: Allys Lindenstrauss
# ID: 235, Name: Renae Scragg
# ID: 236, Name: Bald Ordemann
# ID: 237, Name: Lynda Lehmann
# ID: 238, Name: Odilia Bettles
# ID: 239, Name: Lucretia Ungaretti
# ID: 240, Name: Shandy Blindermann
# ID: 241, Name: Benedetto Ropking
# ID: 242, Name: Francesca Jeffree
# ID: 243, Name: Juliet MacGebenay
# ID: 244, Name: Elspeth Smalls
# ID: 245, Name: Lemuel Thrush
# ID: 246, Name: Neddy O'Garmen
# ID: 247, Name: Lyle Gages
# ID: 248, Name: Hanni Ruit
# ID: 249, Name: Katherina Bundock
# ID: 250, Name: Ruben Pevreal
# ID: 251, Name: Livia Casper
# ID: 252, Name: Merrily Lorey
# ID: 253, Name: Ignacio Warlowe
# ID: 254, Name: Auberta Ingrem
# ID: 255, Name: Doro Diem
# ID: 256, Name: Jobyna Halburton
# ID: 257, Name: Bernie Sushams
# ID: 258, Name: Christabella Chanders
# ID: 259, Name: Lamont Tothe
# ID: 260, Name: Gweneth Allcock
# ID: 261, Name: Barny Arghent
# ID: 262, Name: Anthe Cowderay
# ID: 263, Name: Eldredge Behnecken
# ID: 264, Name: Gui Coogan
# ID: 265, Name: Verile Halliburton
# ID: 266, Name: Michale Goodwins
# ID: 267, Name: Curran Ettels
# ID: 268, Name: Arin Ribeiro
# ID: 269, Name: Garvey Yandell
# ID: 270, Name: Shellie Hastilow
# ID: 271, Name: Jasmin Greeve
# ID: 272, Name: Ashly Janczak
# ID: 273, Name: Lorry Cluely
# ID: 274, Name: Lenee Barzen
# ID: 275, Name: Trevor De Lascy
# ID: 276, Name: Amandi Forst
# ID: 277, Name: Abagael Tomasek
# ID: 278, Name: Ddene Bernardin
# ID: 279, Name: Phaidra Killingworth
# ID: 280, Name: Zoe Coulston
# ID: 281, Name: Ellerey Smithin
# ID: 282, Name: Maudie Sommerlin
# ID: 283, Name: Betti Meran
# ID: 284, Name: Sile Alexsandrev
# ID: 285, Name: Ardeen Tures
# ID: 286, Name: Frances Flemmich
# ID: 287, Name: Dniren Raison
# ID: 288, Name: Katerine Bazeley
# ID: 289, Name: Hetti Narraway
# ID: 290, Name: Cassandre Froude
# ID: 291, Name: Chuck Frankiss
# ID: 292, Name: Brice Johansson
# ID: 293, Name: Arvie Angeau
# ID: 294, Name: Claretta Sloegrave
# ID: 295, Name: Marylou Burrell
# ID: 296, Name: Alfred Saintpierre
# ID: 297, Name: Jarvis Pennings
# ID: 298, Name: Chrysler Frudd
# ID: 299, Name: Jerrilee Bineham
# ID: 300, Name: Saidee Bassett
# ID: 301, Name: Anders Ralston
# ID: 302, Name: Arlene Ferroli
# ID: 303, Name: Hillary Dudenie
# ID: 304, Name: Tildie Julien
# ID: 305, Name: Waneta Dyhouse
# ID: 306, Name: Norby Folkerts
# ID: 307, Name: Danell Poynser
# ID: 308, Name: Rodrigo Thornbarrow
# ID: 309, Name: Aleen Veasey
# ID: 310, Name: Revkah Willans
# ID: 311, Name: Ursulina Curner
# ID: 312, Name: Valma Kruger
# ID: 313, Name: Roberta Kensitt
# ID: 314, Name: Luciano Friman
# ID: 315, Name: Beverie Verralls
# ID: 316, Name: Tades Pezey
# ID: 317, Name: Cammy Liffey
# ID: 318, Name: Mimi Seymour
# ID: 319, Name: Wilt Jagoe
# ID: 320, Name: Artemas Balmer
# ID: 321, Name: Darleen Cranna
# ID: 322, Name: Johnath Fake
# ID: 323, Name: Erv Hubane
# ID: 324, Name: Janna Malitrott
# ID: 325, Name: Abe Bennedick
# ID: 326, Name: Carlota McCrae
# ID: 327, Name: Kevina Collip
# ID: 328, Name: Grace McAless
# ID: 329, Name: Gale Cholwell
# ID: 330, Name: Timotheus Jouannisson
# ID: 331, Name: Darleen Ulyatt
# ID: 332, Name: Nancey Ford
# ID: 333, Name: Margot Francillo
# ID: 334, Name: Tina Sarver
# ID: 335, Name: Arline Athow
# ID: 336, Name: Morissa Habberjam
# ID: 337, Name: Rosemarie Sofe
# ID: 338, Name: Ravid Pigney
# ID: 339, Name: Penelopa Bransby
# ID: 340, Name:
# ID: 341, Name: Bordy Greenman
# ID: 342, Name: Nathanil Conry
# ID: 343, Name: Celestina Eate
# ID: 344, Name: Christen Gilbane
# ID: 345, Name: Corenda Dubbin
# ID: 346, Name: Iris Cariss
# ID: 347, Name: Sumner Gladdis
# ID: 348, Name: Benny Bachelor
# ID: 349, Name: Winona Dudhill
# ID: 350, Name:
# ID: 351, Name: Weston Rouchy
# ID: 352, Name: Eunice Sherbrooke
# ID: 353, Name: Raul Farbrace
# ID: 354, Name: Cobby Solomon
# ID: 355, Name: Carina Libreros
# ID: 356, Name: Johnnie Middle
# ID: 357, Name: Jocelyne Elphinstone
# ID: 358, Name: Kaycee Hounsom
# ID: 359, Name: Justine Yurkevich
# ID: 360, Name: Killy Dracey
# ID: 361, Name: Ike Forgie
# ID: 362, Name: Melodee Suckling
# ID: 363, Name: Cassi Woodard
# ID: 364, Name: Ora Giovanizio
# ID: 365, Name: Fredelia Fendt
# ID: 366, Name: Renee Stoddard
# ID: 367, Name: Ellary Benasik
# ID: 368, Name: Rustie O'Leahy
# ID: 369, Name: Jennifer Walkey
# ID: 370, Name: Luciana Lindenberg
# ID: 371, Name: King Benjamin
# ID: 372, Name: Gabriele Carcas
# ID: 373, Name: Leisha Uccelli
# ID: 374, Name: Far Janicek
# ID: 375, Name: Tracey Cleve
# ID: 376, Name: Gwenore Hallowes
# ID: 377, Name: Guendolen Castro
# ID: 378, Name: Toni Hadleigh
# ID: 379, Name: Ruth Reilly
# ID: 380, Name: Grantley Burnyate
# ID: 381, Name: Stormi Leber
# ID: 382, Name: Bowie Ramsden
# ID: 383, Name: Emmott Blaber
# ID: 384, Name: Milicent Kerner
# ID: 385, Name: Francine Youings
# ID: 386, Name: Hattie Cramphorn
# ID: 387, Name: Dex MacMakin
# ID: 388, Name: Bo Robion
# ID: 389, Name: Emmalynne Smither
# ID: 390, Name: Harp Mayze
# ID: 391, Name: Rania Brend
# ID: 392, Name: Cris Trytsman
# ID: 394, Name: Latrena Brownbill
# ID: 395, Name: Saidee Haddock
# ID: 396, Name: Melisandra Scopyn
# ID: 397, Name: Lefty Checcucci
# ID: 398, Name: Kaitlin Gamlen
# ID: 399, Name: Brose De Michele
# ID: 400, Name: Babita Rusted
# ID: 401, Name: Kori Twinbourne
# ID: 402, Name: Hasty Slipper
# ID: 403, Name: Fergus Weaben
# ID: 404, Name: Chet Ribeiro
# ID: 405, Name: Reyna Yatman
# ID: 406, Name: Isador Martensen
# ID: 407, Name: Doris Summersett
# ID: 408, Name: Bonnibelle Dionsetto
# ID: 409, Name: Annabela Draude
# ID: 410, Name: Vally Kinnard
# ID: 411, Name: Dominic Wornum
# ID: 412, Name: Anna Antalffy
# ID: 413, Name: Berna Jeffrey
# ID: 414, Name: Anderea Penhallurick
# ID: 415, Name: Kari Dimmer
# ID: 416, Name: Jacquette Plumridge
# ID: 417, Name: Jeannette Aizikov
# ID: 418, Name: Gilberta Rippingale
# ID: 419, Name: Hayward Kropp
# ID: 420, Name: Devon Nutty
# ID: 421, Name: Merna Chaimson
# ID: 422, Name: Monika Lamperd
# ID: 423, Name: Rozelle Cullingworth
# ID: 424, Name: Jeana Costanza
# ID: 425, Name: Brenn Novis
# ID: 426, Name: Trumaine Danjoie
# ID: 427, Name: Tara Mertel
# ID: 428, Name: Kristofor Elfitt
# ID: 429, Name: Ashbey Olczyk
# ID: 430, Name: Zed Daymont
# ID: 431, Name: Vyky Parren
# ID: 432, Name: Jerrine Clapperton
# ID: 433, Name: Aarika Britton
# ID: 434, Name: Bernadina Catlette
# ID: 435, Name: Eleanora Dootson
# ID: 436, Name: Chanda Cresser
# ID: 437, Name: Alwin Erdis
# ID: 438, Name: Nanine Bertome
# ID: 439, Name: Florie Allchin
# ID: 440, Name: Oren Geaveny
# ID: 441, Name: Irwin Beaulieu
# ID: 442, Name: Hale Oleszcuk
# ID: 443, Name: Cherey Iacopini
# ID: 444, Name: Jacenta Cullnean
# ID: 445, Name: Gilles Houdhury
# ID: 446, Name: Risa Simek
# ID: 447, Name: Midge Delacour
# ID: 448, Name: Greg Dorie
# ID: 449, Name: Emory Nobes
# ID: 450, Name: Loise Bartens
# ID: 451, Name: Avrit Barrett
# ID: 452, Name: Truman Davidman
# ID: 453, Name: Liz McCaghan
# ID: 454, Name: Gilda Rudolfer
# ID: 455, Name: Rodge Seston
# ID: 456, Name: Rivi Van der Merwe
# ID: 457, Name: Marcelline Masding
# ID: 458, Name: Norean Foker
# ID: 459, Name: Maisey Markie
# ID: 460, Name: Melva Goodge
# ID: 461, Name: Alfi Keepe
# ID: 462, Name: Correna Samter
# ID: 463, Name: Shell Castleman
# ID: 464, Name: Fanchette Sowrah
# ID: 465, Name: Hamnet Wooldridge
# ID: 466, Name: Chandler Amesbury
# ID: 467, Name: Sully Kubicki
# ID: 468, Name: Leela Mowatt
# ID: 469, Name: Shelby Reaveley
# ID: 470, Name: Lianne Huxton
# ID: 471, Name: Ethelda Owbrick
# ID: 472, Name: Payton Palmer
# ID: 473, Name: Berk Stennes
# ID: 474, Name: Calhoun Pester
# ID: 475, Name: Lebbie Ruberry
# ID: 476, Name: Friedrich Loton
# ID: 477, Name: Loella Cudiff
# ID: 478, Name: Tersina Shackelton
# ID: 479, Name: Doria Buard
# ID: 480, Name: Brena Issatt
# ID: 481, Name: Eileen Spikeings
# ID: 482, Name: Emmalynn Robilliard
# ID: 483, Name: Paco Truter
# ID: 484, Name: Arlene Piletic
# ID: 485, Name: Hill Oakeby
# ID: 486, Name: Joanie Janjusevic
# ID: 487, Name: Fanechka Cescon
# ID: 488, Name: Samantha Mundie
# ID: 489, Name: Arabelle Churching
# ID: 490, Name: Mathew Wyre
# ID: 491, Name: Liane Gladtbach
# ID: 492, Name: Lesya Zebedee
# ID: 493, Name: Dalis Coughan
# ID: 494, Name: Fredericka Blezard
# ID: 495, Name: Seth Kubacek
# ID: 496, Name: Carissa Bartel
# ID: 497, Name: Teddi Eadmeades
# ID: 498, Name: Teriann Bukowski
# ID: 499, Name: Holly Akehurst
# ID: 500, Name: Audrye Fazakerley
# ID: 501, Name: Adaline Sherrett
# ID: 502, Name: Myrtle Kenan
# ID: 503, Name: Anjanette Snepp
# ID: 504, Name: Avrit Henniger
# ID: 505, Name: Andi Norwich
# ID: 506, Name: Joye Pinson
# ID: 507, Name: Nonie Threadgould
# ID: 508, Name: Tommy Dehn
# ID: 509, Name: Tiphanie Neads
# ID: 510, Name: Zelda Sheavills
# ID: 511, Name: Cecilia Keynd
# ID: 512, Name: Malia Dungay
# ID: 513, Name: Garald McPhillips
# ID: 514, Name: Francis Jantel
# ID: 515, Name: Stephenie Yeowell
# ID: 516, Name: Kerry Neno
# ID: 517, Name: Falito Bellay
# ID: 518, Name: Cassandra McRobert
# ID: 519, Name: Perkin Brookbank
# ID: 520, Name: Kial Dulwitch
# ID: 521, Name: Paulita Cumberbatch
# ID: 522, Name: Gina Cutill
# ID: 523, Name: Darelle Wogden
# ID: 524, Name: Jacenta Pieterick
# ID: 525, Name: Maiga Jarmain
# ID: 526, Name: Vivie Darwood
# ID: 527, Name: Maxy Agnolo
# ID: 528, Name: Doyle Lawden
# ID: 529, Name: Deena Semarke
# ID: 530, Name: Jacques Branno
# ID: 531, Name: Daune Leaning
# ID: 532, Name: Alfreda Stittle
# ID: 534, Name: Rex Gligoraci
# ID: 535, Name: Jorry Koppel
# ID: 536, Name: Mellicent Grisard
# ID: 537, Name: Marya Norcutt
# ID: 538, Name: Rafferty Ferrettini
# ID: 539, Name: Grace Caulwell
# ID: 540, Name: Chrysler Cogswell
# ID: 541, Name: Jennie Greenway
# ID: 542, Name: Dewie Avann
# ID: 543, Name: Melodie Frazier
# ID: 544, Name: Curr Lafrentz
# ID: 545, Name: Allan Rickert
# ID: 546, Name: Zack Scroxton
# ID: 547, Name: Kirsteni Keatley
# ID: 548, Name: Pegeen Piccard
# ID: 549, Name: Antonina Semble
# ID: 550, Name: Ellene Cunnow
# ID: 551, Name: Lind Flips
# ID: 552, Name: Quintus McCallister
# ID: 553, Name: Bobette Buyers
# ID: 554, Name: Eziechiele Donson
# ID: 555, Name: Annabella Telezhkin
# ID: 556, Name: Giff Kelson
# ID: 557, Name: Kamila Collumbine
# ID: 558, Name: Avivah Dymond
# ID: 559, Name: Woodman Dake
# ID: 560, Name: Zena Buck
# ID: 561, Name: Saxon Eastop
# ID: 562, Name: Letisha Le Floch
# ID: 563, Name: Sharona Tweedy
# ID: 564, Name: Pietro Ogdahl
# ID: 565, Name: Karen Withnall
# ID: 566, Name: Ingrim Orrum
# ID: 567, Name: Annabelle Southon
# ID: 568, Name: Jody Ireland
# ID: 569, Name: Newton MacColl
# ID: 570, Name: Cati Orbell
# ID: 571, Name:
# ID: 572, Name: Bethena Nissle
# ID: 573, Name: Hynda Wheatcroft
# ID: 574, Name: Laura Ginley
# ID: 575, Name: Edgard Sawden
# ID: 576, Name: Noak Windmill
# ID: 577, Name: Kenneth Ravenscroftt
# ID: 578, Name: Garfield Giovanitti
# ID: 579, Name: Deane Stivani
# ID: 580, Name: Eugenio Crumly
# ID: 581, Name: Gris Heino
# ID: 582, Name: Adams Whitington
# ID: 583, Name: Chrotoem Johanning
# ID: 584, Name: Renado Terne
# ID: 585, Name: Sonja Vero
# ID: 586, Name: Roanne Brant
# ID: 587, Name: Deina Magovern
# ID: 588, Name: Gabriell Paffitt
# ID: 589, Name: Emmeline Hantusch
# ID: 590, Name: Niven Morter
# ID: 591, Name: Antonia Ferdinand
# ID: 592, Name: Anni Mewton
# ID: 593, Name: Ruthi Liversedge
# ID: 594, Name: Vinny Liggins
# ID: 595, Name: Charita Wyldish
# ID: 596, Name: Noble Spere
# ID: 597, Name: Rahal Callf
# ID: 598, Name: Hope Yakovliv
# ID: 599, Name: Chrystal Kopje
# ID: 600, Name: Niels Jendrys
# ID: 601, Name: Vincents Lees
# ID: 602, Name: Gamaliel Simonnin
# ID: 603, Name: Zulema McGiffie
# ID: 604, Name: Trace Bowe
# ID: 605, Name: Matteo De Clairmont
# ID: 606, Name: Mitzi Zoane
# ID: 607, Name: Inglis Toogood
# ID: 608, Name: Rita Rakes
# ID: 609, Name: Doyle Galpen
# ID: 610, Name: Andreas Adkin
# ID: 611, Name: Hill Anders
# ID: 612, Name: Jazmin Orgel
# ID: 613, Name: Sigrid Leversha
# ID: 614, Name: Shawn O'Kinneally
# ID: 615, Name: Jillana Neeson
# ID: 616, Name: Emlen Whitton
# ID: 617, Name: Valenka Annwyl
# ID: 618, Name: Hasheem De la Yglesia
# ID: 619, Name: Karlene Hendonson
# ID: 620, Name: Cilka Cariss
# ID: 621, Name: Sheri Vice
# ID: 622, Name: Dodie Codlin
# ID: 623, Name:
# ID: 624, Name: Stearne Boord
# ID: 625, Name: Toddy Bragger
# ID: 626, Name: Maribeth Stirtle
# ID: 627, Name: Deanne Pilcher
# ID: 628, Name: Adan Simonds
# ID: 629, Name: Goldia Gottelier
# ID: 630, Name: Adler Allon
# ID: 631, Name: Yettie Tellenbrok
# ID: 632, Name: Loree Dytham
# ID: 633, Name: Charline Axtell
# ID: 634, Name: Duff Bauld
# ID: 635, Name: Winne Kemet
# ID: 636, Name: Adair Spellessy
# ID: 637, Name: Serena Iacovolo
# ID: 638, Name: Revkah Franke
# ID: 639, Name: Candis Brayshay
# ID: 640, Name: Auguste Savage
# ID: 641, Name: Muffin Oldall
# ID: 642, Name: Ronda Prichard
# ID: 643, Name: Andi Haylett
# ID: 644, Name: Bjorn Cremen
# ID: 645, Name: Hedvige Vogelein
# ID: 646, Name: Shelagh Scoffins
# ID: 647, Name: Flori Priscott
# ID: 648, Name: August Scotsbrook
# ID: 649, Name: Karina Brunt
# ID: 650, Name: Callida Helmke
# ID: 651, Name: Shirlee Morcomb
# ID: 652, Name: Corabel Fowlestone
# ID: 653, Name: Catlee Baroc
# ID: 654, Name: Gloria Semechik
# ID: 655, Name: Juliette Josuweit
# ID: 656, Name: Fayina Trevarthen
# ID: 657, Name: Gawen Saggs
# ID: 658, Name: Valeria Bidwell
# ID: 659, Name: Tailor Phizakarley
# ID: 660, Name: Beaufort Fifoot
# ID: 661, Name: Winnie Nalder
# ID: 662, Name: Ingunna Sikorski
# ID: 664, Name: Meara Leipelt
# ID: 665, Name: Noah Blazejewski
# ID: 666, Name: Rad Malt
# ID: 667, Name: Jinny Navarre
# ID: 668, Name: Larry Markus
# ID: 669, Name: Shannan Wollen
# ID: 670, Name: Cordelia Hembling
# ID: 671, Name: Ernaline Stroulger
# ID: 672, Name: Windham Biesterfeld
# ID: 673, Name: Cosette Briffett
# ID: 674, Name: Marita Wakeman
# ID: 675, Name: Roxanna Verny
# ID: 676, Name: My Challice
# ID: 677, Name: Karel Lyne
# ID: 678, Name: Rhonda Rembaud
# ID: 679, Name: Aguste Baseley
# ID: 680, Name: Werner Baldrick
# ID: 681, Name: Janek Fleay
# ID: 682, Name: Noemi Brignall
# ID: 683, Name: Fidel Massimo
# ID: 684, Name: D'arcy Lunam
# ID: 686, Name: Bessy Feavers
# ID: 687, Name: Evaleen Dotterill
# ID: 688, Name: Hamel Bearman
# ID: 689, Name: Jacquelin O'Farrell
# ID: 690, Name: Sarene Ilyinykh
# ID: 691, Name: Benedetto Heazel
# ID: 692, Name: Algernon McCraw
# ID: 693, Name: Rebeca Rubinsohn
# ID: 694, Name: Fergus Fiddler
# ID: 695, Name: Gillan Sheber
# ID: 696, Name: Evered Schindler
# ID: 697, Name: Sumner Paulisch
# ID: 698, Name: Daloris D'Ambrosio
# ID: 699, Name: Nettle Armstrong
# ID: 700, Name: Amos Oneal
# ID: 701, Name: Clarie Dionsetti
# ID: 702, Name: Ettore Duigan
# ID: 703, Name: Ahmed Cristofolini
# ID: 704, Name: Linell Bocken
# ID: 705, Name: Bonita Bethune
# ID: 706, Name: Valentina MacTavish
# ID: 707, Name: Berty Ollivierre
# ID: 708, Name: Charles Bleesing
# ID: 709, Name: Nev Doghartie
# ID: 710, Name: Augusto Etherson
# ID: 711, Name: Andra Walthall
# ID: 712, Name: Cathrin Bourke
# ID: 713, Name: Isa Blees
# ID: 714, Name: Mala Divina
# ID: 715, Name: Isobel Brettle
# ID: 716, Name: Evered Cowland
# ID: 717, Name: Marcelo Lakeland
# ID: 718, Name: Berty Matei
# ID: 719, Name: Delmer McCory
# ID: 720, Name: Shaine Pavlenko
# ID: 721, Name: Marge Pagelsen
# ID: 722, Name: Cherilynn Limpenny
# ID: 723, Name: Alexandrina Sambiedge
# ID: 724, Name: Bliss Braim
# ID: 725, Name: Tomas Chesson
# ID: 726, Name: Leigh Rittelmeyer
# ID: 727, Name: Raynor Comber
# ID: 728, Name: Kelwin Voysey
# ID: 729, Name: Milty Spence
# ID: 730, Name: Rodolphe Assiter
# ID: 731, Name: Maynord Swainsbury
# ID: 732, Name: Cyrille Veazey
# ID: 733, Name: Parsifal Bernardon
# ID: 734, Name: Rock Reach
# ID: 735, Name: Chrissie Adcock
# ID: 736, Name: Chalmers Aplin
# ID: 737, Name: Kissiah Edmeades
# ID: 738, Name: Ettore Mulcock
# ID: 739, Name: Rafael Seddon
# ID: 740, Name: Jonie Schapero
# ID: 741, Name: Malachi Loxton
# ID: 742, Name: Wadsworth Streatfeild
# ID: 743, Name: Georg Prince
# ID: 744, Name: Jilli Feechum
# ID: 745, Name: Mickie Haverson
# ID: 746, Name: Lorette Barkhouse
# ID: 747, Name: Lettie Braden
# ID: 748, Name: Indira Pitkeathley
# ID: 749, Name: Roseanne Emps
# ID: 750, Name: Alidia Fulmen
# ID: 751, Name: Zarah Swigger
# ID: 752, Name: Dennet Skaif
# ID: 753, Name: Victoria Kordt
# ID: 754, Name: Aldis Branford
# ID: 755, Name: Cass Wilton
# ID: 756, Name: Rickie Sacher
# ID: 757, Name: Patrizio Billingsly
# ID: 759, Name: Stern Di Biaggi
# ID: 760, Name: Giuditta Mower
# ID: 761, Name: Adi Tilburn
# ID: 762, Name: Frank Creane
# ID: 763, Name: Rozella Domleo
# ID: 764, Name: Nancee Jakubczyk
# ID: 765, Name: Rosemary Brabyn
# ID: 766, Name:
# ID: 767, Name: Heinrik Fucher
# ID: 768, Name: Moises Matysik
# ID: 769, Name: Alena Colliver
# ID: 770, Name: Ally Binley
# ID: 771, Name: Theo Simcock
# ID: 772, Name: Loralyn Carnie
# ID: 773, Name:
# ID: 774, Name: Agata Magrane
# ID: 775, Name: Clarice Maun
# ID: 776, Name: Cele Marciek
# ID: 777, Name: Milo Geraldez
# ID: 778, Name: Ross Fuggle
# ID: 779, Name: Darwin Rycroft
# ID: 780, Name: Annabelle Edmonston
# ID: 781, Name: Junina Vasishchev
# ID: 782, Name: Risa Kiddye
# ID: 783, Name: Herve Shakespeare
# ID: 784, Name: Selby Raspison
# ID: 785, Name: Torey Spadelli
# ID: 786, Name: Virgie Yong
# ID: 787, Name: Flossi Hernik
# ID: 788, Name: Christie Hadlow
# ID: 790, Name: Emmie Baly
# ID: 791, Name: Theda Mossman
# ID: 793, Name: Shanna Luisetti
# ID: 794, Name: Loise Watkiss
# ID: 795, Name: Bonny Storms
# ID: 796, Name: Roxane McCahill
# ID: 797, Name: Ruddie De Morena
# ID: 798, Name: Bridie Burless
# ID: 799, Name: Kristien Leeds
# ID: 800, Name: Karylin Glusby
# ID: 801, Name: Ursala Cloy
# ID: 802, Name: Kelley Prop
# ID: 803, Name: Vivyanne Bohlens
# ID: 804, Name: Gracia Sibylla
# ID: 805, Name: Rudie Omand
# ID: 806, Name: Barth Plott
# ID: 807, Name: Emmet Gridon
# ID: 808, Name: Electra Frary
# ID: 809, Name: Krishnah Gilham
# ID: 810, Name: Lia Marshal
# ID: 811, Name: Georgeanna Egan
# ID: 812, Name: Izzy Hammerson
# ID: 813, Name: Betty Juara
# ID: 814, Name: Theodore Pigeon
# ID: 815, Name: Lucian Carmo
# ID: 816, Name: Caralie Landrick
# ID: 817, Name: Virge Algar
# ID: 818, Name: Yancy Tapply
# ID: 819, Name: Winnah Benthall
# ID: 820, Name: Myrna Buse
# ID: 821, Name: Lindsay Yven
# ID: 822, Name: Ericha Doohan
# ID: 823, Name: Barr Benam
# ID: 825, Name: Daisi Glasscock
# ID: 826, Name: Holly Pietroni
# ID: 827, Name: Opalina Dowdell
# ID: 828, Name: Rickey Pickering
# ID: 829, Name: Cory Lawlan
# ID: 830, Name: Charla Pottes
# ID: 831, Name:
# ID: 833, Name: Essa Cottingham
# ID: 834, Name: Kurtis Dallin
# ID: 835, Name: Coleman Friary
# ID: 836, Name: Jorgan Hillaby
# ID: 837, Name: Wilton Muldrew
# ID: 838, Name: Sheeree Romei
# ID: 839, Name: Camille Brumble
# ID: 840, Name: Haily Dicken
# ID: 841, Name: Burlie Cuttin
# ID: 842, Name: Lelah Syder
# ID: 843, Name: Julio Pallaske
# ID: 844, Name: Agnesse Fazan
# ID: 845, Name: Knox Kinig
# ID: 846, Name: Rouvin Gatch
# ID: 847, Name: Myrtia Bertrand
# ID: 848, Name: Randolph Revance
# ID: 849, Name: Melina Pires
# ID: 850, Name: Chryste Farndell
# ID: 851, Name: Karna Miles
# ID: 852, Name: Titus Shotter
# ID: 853, Name: Meryl Bellerby
# ID: 854, Name: Normie Haugen
# ID: 855, Name: Hanna Ilyas
# ID: 856, Name: Quinta Biddell
# ID: 857, Name: Joyann Trump
# ID: 858, Name: Cirilo Kemer
# ID: 859, Name: Saree Balnaves
# ID: 860, Name: Marin Elington
# ID: 861, Name: Ferdinanda Montel
# ID: 862, Name: Yoko Minards
# ID: 863, Name: Rafferty Queste
# ID: 864, Name: Alane James
# ID: 865, Name: Sebastian Fereday
# ID: 866, Name: Nessie Attoc
# ID: 867, Name: Betsey Sweed
# ID: 868, Name: Josefina Shaughnessy
# ID: 869, Name: Cesaro Neggrini
# ID: 870, Name: Baldwin Purvess
# ID: 871, Name: Toiboid Opdenorth
# ID: 872, Name: Hedwig Cuningham
# ID: 873, Name: Aldous Walworche
# ID: 874, Name: Lorettalorna Spyer
# ID: 875, Name: Florencia Ealden
# ID: 876, Name: Ignacio Cutmare
# ID: 877, Name: Tadio Low
# ID: 878, Name: Billie Clyburn
# ID: 879, Name: Waylin Horsfield
# ID: 880, Name: Lotti Flewett
# ID: 881, Name: Frederich Roswarn
# ID: 882, Name: Carleen Catterill
# ID: 883, Name: Batholomew Shorbrook
# ID: 884, Name: Joey Kobera
# ID: 885, Name: Lorne Halfhead
# ID: 886, Name: Judy Beynke
# ID: 887, Name: Trudey Jellard
# ID: 888, Name: Willetta Wickey
# ID: 889, Name: Sibylla Abram
# ID: 890, Name: Carlina Rilston
# ID: 891, Name: Brandy Prestney
# ID: 892, Name: Thedrick Glew
# ID: 893, Name: Nertie Sigward
# ID: 894, Name: Catina Adamowitz
# ID: 895, Name: Adela Ivain
# ID: 896, Name: Mata Yanukhin
# ID: 897, Name: Pasquale Wreiford
# ID: 898, Name: Amye Pauel
# ID: 899, Name: Helen-elizabeth Culpin
# ID: 900, Name: Darb Holberry
# ID: 901, Name: Hyacinthie Sillick
# ID: 902, Name: Diandra Malkinson
# ID: 903, Name: Carolyn Stebbing
# ID: 904, Name: Roi Drakers
# ID: 905, Name: Lib Monahan
# ID: 906, Name: Currie Brettle
# ID: 907, Name: Maurizio Gorman
# ID: 908, Name: Roxy Heinrici
# ID: 909, Name: Zebedee MacFaell
# ID: 910, Name: Bar O'Keefe
# ID: 911, Name: Darill Josse
# ID: 912, Name: Ottilie Vearncomb
# ID: 913, Name: Moll Danat
# ID: 914, Name: Freeman Felderer
# ID: 915, Name: Hyatt Oulett
# ID: 916, Name: Nanon Grishechkin
# ID: 917, Name: Gaby Peschka
# ID: 918, Name: Brooke Liddel
# ID: 919, Name: Bobbie Stickells
# ID: 920, Name: Herculie Wolfart
# ID: 921, Name: Dion Aveling
# ID: 922, Name: Vincents Phillipp
# ID: 923, Name: Gill Cocks
# ID: 924, Name: Brunhilde Taggert
# ID: 925, Name: Cary Vedyasov
# ID: 926, Name: Kath Greste
# ID: 927, Name: Lamond Klimaszewski
# ID: 928, Name: Leroi Flynn
# ID: 929, Name: Antonin Sabbins
# ID: 930, Name: Jorrie Obin
# ID: 931, Name: Wilhelmine Coulthard
# ID: 933, Name: Albrecht Karolowski
# ID: 934, Name: Spence Sponer
# ID: 935, Name: Noelle Garm
# ID: 936, Name: Nelly Vasnetsov
# ID: 937, Name:
# ID: 938, Name: Gillie Akess
# ID: 939, Name: Keeley Erie
# ID: 940, Name: Klara Grumell
# ID: 941, Name: Jennee McNirlan
# ID: 943, Name: Samson Folomin
# ID: 944, Name: Rhonda Jephcote
# ID: 945, Name: Lavinie Josey
# ID: 946, Name: Ellsworth Vedyasov
# ID: 947, Name: Paton Frary
# ID: 948, Name: Alexandre Ibanez
# ID: 949, Name: Guinevere Spence
# ID: 950, Name: Devy Willarton
# ID: 951, Name: Beaufort Bhar
# ID: 952, Name: Krisha Bettlestone
# ID: 953, Name: Garwood Boosey
# ID: 954, Name: Vevay Donneely
# ID: 956, Name: Brena Myrick
# ID: 957, Name: Jud Clash
# ID: 958, Name: Esdras Milburne
# ID: 959, Name: Marylinda Ellam
# ID: 960, Name: Daphene Lovemore
# ID: 962, Name: Guinna Facey
# ID: 963, Name: Stevie Daniels
# ID: 964, Name: Baldwin Hobgen
# ID: 965, Name: Lita Jahner
# ID: 966, Name: Gertrud Magson
# ID: 967, Name: Jessee Lopez
# ID: 968, Name: Gunar Sreenan
# ID: 969, Name: Dulcea Banner
# ID: 970, Name:
# ID: 971, Name: Katherina Garoghan
# ID: 972, Name: Bridgette Sapseed
# ID: 973, Name: Stanleigh Welbeck
# ID: 974, Name: Hewet Civitillo
# ID: 975, Name: Gina MacAllen
# ID: 976, Name: Gerrard Clewett
# ID: 977, Name: Tremain Kenningley
# ID: 978, Name: Harwilll Mattiato
# ID: 979, Name: Marney Oslar
# ID: 980, Name: Crystal Bangham
# ID: 981, Name: Hadlee Bonnar
# ID: 982, Name: Kermy Bunton
# ID: 983, Name: Felicia Gunton
# ID: 984, Name: Violette Hallewell
# ID: 985, Name: Erena Search
# ID: 986, Name: Starla Drugan
# ID: 987, Name: Shaina Shervington
# ID: 988, Name: Danya Kid
# ID: 989, Name: Sherrie Armor
# ID: 990, Name: Claudian Eardley
# ID: 991, Name: Alissa Stafford
# ID: 992, Name: Tad Rowan
# ID: 993, Name: Maggy Mendez
# ID: 994, Name: Hedi Parramore
# ID: 995, Name: Goran Carde
# ID: 996, Name: Cirstoforo Pettipher
# ID: 997, Name: Wilek O'Cridigan
# ID: 998, Name: Jerry Ducker
# ID: 999, Name: Jerri Osmar
# ID: 1000, Name: Vivian O'Boyle
# ID: 1001, Name: Harold Abram
# ID: 1002, Name: Ty Adamowitz
# ID: 1003, Name: Lyman Adcock
# ID: 1004, Name: Lotti Adkin
# ID: 1005, Name: Gretna Agnolo
# ID: 1006, Name: Marlow Aizikov
# ID: 1007, Name: Joan Akehurst
# ID: 1008, Name: Ulrick Akess
# ID: 1009, Name: Lucretia Alabaster
# ID: 1010, Name: Arty Alexsandrev
# ID: 1011, Name: Libbi Algar
# ID: 1012, Name: Jacky Allchin
# ID: 1013, Name: Raine Allcock
# ID: 1014, Name: Melonie Allon
# ID: 1015, Name: Robers Amesbury
# ID: 1016, Name: Bone Anders
# ID: 1017, Name: Andee Andri
# ID: 1018, Name: Gay Andriesse
# ID: 1019, Name: Loralie Andrzejczak
# ID: 1020, Name: Tobi Angeau
# ID: 1021, Name: Mandel Annwyl
# ID: 1022, Name: Toddy Antalffy
# ID: 1023, Name: Jeremias Antecki
# ID: 1024, Name: Lemar Aplin
# ID: 1025, Name: Tanner Arboin
# ID: 1026, Name: Bartolomeo Arghent
# ID: 1027, Name: Elvina Armor
# ID: 1028, Name: Letitia Armstrong
# ID: 1029, Name: Warner Aronsohn
# ID: 1030, Name: Geri Ashpital
# ID: 1031, Name: Jerald Assiter
# ID: 1032, Name: Wilt Astbury
# ID: 1033, Name: Aldwin Athow
# ID: 1034, Name: Corena Attoc
# ID: 1035, Name: Malchy Avann
# ID: 1036, Name: Gasparo Aveling
# ID: 1037, Name: Nikkie Axtell
# ID: 1038, Name: Louisa Bachelor
# ID: 1039, Name: Brook Backen
# ID: 1040, Name: Cly Baldrick
# ID: 1041, Name: Jena Balmer
# ID: 1042, Name: Pail Balnaves
# ID: 1043, Name: Agneta Baly
# ID: 1044, Name: Lanae Bangham
# ID: 1045, Name: Gipsy Banner
# ID: 1046, Name: Philly Barhims
# ID: 1047, Name: Jimmie Barkhouse
# ID: 1048, Name: Lonee Baroc
# ID: 1049, Name:
# ID: 1050, Name: Marybelle Barribal
# ID: 1051, Name: Moe Bartel
# ID: 1052, Name: Trudie Bartens
# ID: 1053, Name: Rebbecca Barzen
# ID: 1054, Name: Bevin Baseley
# ID: 1055, Name: Marielle Baselio
# ID: 1056, Name: Orelie Bassett
# ID: 1057, Name: Meggie Bastin
# ID: 1058, Name: Elia Baton
# ID: 1059, Name: Sharron Battlestone
# ID: 1060, Name: Washington Bauld
# ID: 1061, Name: Artemus Bazeley
# ID: 1062, Name: Lou Bazely
# ID: 1063, Name: Tanhya Bearman
# ID: 1064, Name: Florella Beaulieu
# ID: 1065, Name: Saundra Beecraft
# ID: 1066, Name: Redford Behnecken
# ID: 1067, Name: Thia Bellay
# ID: 1068, Name: Perceval Bellerby
# ID: 1069, Name: Sidoney Benam
# ID: 1070, Name: Ted Benasik
# ID: 1071, Name: Brandea Benjamin
# ID: 1072, Name: Judy Bennedick
# ID: 1073, Name: Matthus Benthall
# ID: 1074, Name: Wilma Bere
# ID: 1075, Name: Xylia Bernadot
# ID: 1076, Name: Carver Bernardin
# ID: 1077, Name: Fayette Bernardon
# ID: 1078, Name: Christalle Bertome
# ID: 1079, Name: Ashley Bertrand
# ID: 1080, Name: Angelika Beslier
# ID: 1081, Name: Caril Bethune
# ID: 1082, Name: Lief Bettles
# ID: 1083, Name: Barth Bettlestone
# ID: 1084, Name: Ludvig Bewsey
# ID: 1085, Name: Dev Beynke
# ID: 1086, Name: Vinnie Bhar
# ID: 1087, Name: Cirstoforo Biddell
# ID: 1088, Name: Rosabelle Bidwell
# ID: 1089, Name: Rodrique Biesterfeld
# ID: 1090, Name: Germana Billin
# ID: 1091, Name: Rolf Billingsly
# ID: 1093, Name: Belinda Binion
# ID: 1094, Name: Zachariah Binley
# ID: 1096, Name: Creight Blazejewski
# ID: 1097, Name: Beltran Blees
# ID: 1099, Name: Marlo Blezard
# ID: 1100, Name: Karita Blindermann
# ID: 1101, Name: Jenn Blundin
# ID: 1102, Name: Ogden Bocken
# ID: 1103, Name: Cathy Bohlens
# ID: 1104, Name: Wenda Bonnar
# ID: 1105, Name: Jewelle Boord
# ID: 1106, Name: Jasper Boosey
# ID: 1107, Name: Welby Bote
# ID: 1108, Name: Marlie Bothen
# ID: 1109, Name: Bethanne Bourke
# ID: 1111, Name: Zsazsa Brabyn
# ID: 1112, Name: Brett Braden
# ID: 1113, Name: Carlee Bragger
# ID: 1114, Name: Grady Braim
# ID: 1115, Name: Wilbert Branchet
# ID: 1116, Name: Ardys Branford
# ID: 1117, Name: Putnem Branno
# ID: 1118, Name: Blondell Bransby
# ID: 1119, Name: Lucky Brant
# ID: 1120, Name: Brietta Brayshay
# ID: 1121, Name: Cristy Brend
# ID: 1122, Name: Gnni Brettle
# ID: 1123, Name: Alisha Brettle
# ID: 1124, Name: Merrill Bridgeman
# ID: 1125, Name: Gerri Bridie
# ID: 1126, Name: Olly Briffett
# ID: 1127, Name: Corinne Brignall
# ID: 1128, Name: Reuven Brisson
# ID: 1129, Name: Stephana Britton
# ID: 1130, Name:
# ID: 1131, Name: Angie Brommage
# ID: 1132, Name: Gypsy Brookbank
# ID: 1133, Name: Jennine Brownbill
# ID: 1134, Name: Lacee Brumble
# ID: 1135, Name: Foster Brunt
# ID: 1136, Name: Meryl Buard
# ID: 1137, Name: Ichabod Buck
# ID: 1138, Name: Conrad Bukowski
# ID: 1139, Name: Celina Bundock
# ID: 1140, Name: Putnam Bunton
# ID: 1141, Name: Marylin Burgot
# ID: 1142, Name: Reginald Burless
# ID: 1143, Name: Elston Burnyate
# ID: 1144, Name: Angel Burrell
# ID: 1145, Name: Gretel Buse
# ID: 1146, Name: Deirdre Butt
# ID: 1147, Name: Gaston Buyers
# ID: 1148, Name: Rourke Bycraft
# ID: 1149, Name: Katlin Cabrera
# ID: 1150, Name: Valentia Callf
# ID: 1151, Name: Jarrett Camelli
# ID: 1152, Name: Kori Carcas
# ID: 1153, Name: Truman Carde
# ID: 1154, Name: Lurette Caris
# ID: 1155, Name: Jewel Cariss
# ID: 1156, Name: Mikel Cariss
# ID: 1157, Name: Kellia Carmo
# ID: 1158, Name: Rube Carnie
# ID: 1159, Name: Gayleen Carnihan
# ID: 1160, Name: Sher Casale
# ID: 1161, Name: Nobe Casper
# ID: 1162, Name: Raff Castleman
# ID: 1163, Name: Nerta Castro
# ID: 1164, Name: Geraldine Catlette
# ID: 1165, Name: Charleen Catterill
# ID: 1166, Name: Hollis Caulwell
# ID: 1167, Name: Alexis Cawthery
# ID: 1168, Name: Toinette Cescon
# ID: 1169, Name: Dannye Chaimson
# ID: 1170, Name:
# ID: 1171, Name: Charis Chanders
# ID: 1172, Name: Roselle Chatto
# ID: 1173, Name: Myra Checcucci
# ID: 1174, Name: Anetta Chesson
# ID: 1175, Name: Billy Chifney
# ID: 1176, Name: Barbie Chittenden
# ID: 1177, Name: Ardella Cholwell
# ID: 1178, Name: Petronilla Chowne
# ID: 1179, Name: Wolfy Churching
# ID: 1180, Name: Siobhan Ciobutaru
# ID: 1181, Name: Joeann Civitillo
# ID: 1182, Name: Renell Clapperton
# ID: 1183, Name: Peyton Clash
# ID: 1184, Name: Alanson Cleve
# ID: 1185, Name: Ryley Clewett
# ID: 1186, Name: Claudelle Cloy
# ID: 1187, Name: Janna Cluely
# ID: 1188, Name: Regen Cluer
# ID: 1189, Name: Donny Clyburn
# ID: 1190, Name: Amalia Cockell
# ID: 1191, Name: Caldwell Cocks
# ID: 1192, Name: Olia Codlin
# ID: 1193, Name: Sarita Cogswell
# ID: 1194, Name: Lonny Collip
# ID: 1195, Name:
# ID: 1196, Name: Harriot Collumbine
# ID: 1197, Name: Mellie Comber
# ID: 1198, Name: Carline Comberbach
# ID: 1199, Name: Fields Conman
# ID: 1200, Name: Erick Conry
# ID: 1201, Name: Brien Constantine
# ID: 1202, Name: Irving Coogan
# ID: 1203, Name: Kienan Corington
# ID: 1204, Name: Dana Costanza
# ID: 1205, Name: Phillis Cottingham
# ID: 1206, Name: Osbourne Coughan
# ID: 1207, Name: Ahmad Coule
# ID: 1208, Name: Rasia Coulston
# ID: 1209, Name: Tova Coulthard
# ID: 1210, Name: Babita Cowderay
# ID: 1211, Name: Berny Cowland
# ID: 1212, Name: Alan Cramphorn
# ID: 1213, Name: Brody Cranna
# ID: 1214, Name: Hermann Creane
# ID: 1215, Name: Ewart Cremen
# ID: 1216, Name: Theobald Cresser
# ID: 1217, Name: Marleen Cristofolini
# ID: 1218, Name: Stephie Crocumbe
# ID: 1219, Name: Malorie Crowthe
# ID: 1220, Name: Aile Crumly
# ID: 1221, Name: Valentia Cudiff
# ID: 1222, Name: Blakelee Cullingworth
# ID: 1223, Name: Malvina Cullnean
# ID: 1224, Name: Hirsch Culpin
# ID: 1225, Name: Barnabas Cumberbatch
# ID: 1226, Name: Hedy Cuningham
# ID: 1227, Name: Jeramey Cunnow
# ID: 1228, Name: Jobi Curner
# ID: 1229, Name: Luke Cutill
# ID: 1230, Name: Arley Cutmare
# ID: 1231, Name: Daisie Cutteridge
# ID: 1232, Name: Zach Cuttin
# ID: 1233, Name: Tony D'Ambrosio
# ID: 1234, Name: Allys D'Enrico
# ID: 1235, Name: Renae Daber
# ID: 1236, Name: Bald Dake
# ID: 1237, Name: Lynda Dallin
# ID: 1238, Name: Odilia Danat
# ID: 1239, Name: Lucretia Daniels
# ID: 1240, Name: Shandy Danjoie
# ID: 1241, Name: Benedetto Darwood
# ID: 1242, Name: Francesca Davidman
# ID: 1243, Name: Juliet Daymont
# ID: 1244, Name: Elspeth De Clairmont
# ID: 1245, Name: Lemuel De Gregoli
# ID: 1246, Name: Neddy De la Yglesia
# ID: 1247, Name: Lyle De Lascy
# ID: 1248, Name: Hanni De Michele
# ID: 1249, Name: Katherina De Morena
# ID: 1250, Name: Ruben Dehn
# ID: 1251, Name: Livia Delacour
# ID: 1253, Name: Ignacio Di Francesco
# ID: 1254, Name: Auberta Dicken
# ID: 1255, Name: Doro Dickey
# ID: 1256, Name: Jobyna Diem
# ID: 1257, Name: Bernie Dilrew
# ID: 1258, Name: Christabella Dimitriev
# ID: 1259, Name: Lamont Dimmer
# ID: 1260, Name: Gweneth Dionsetti
# ID: 1261, Name: Barny Dionsetto
# ID: 1262, Name: Anthe Divina
# ID: 1263, Name: Eldredge Dockerty
# ID: 1264, Name: Gui Dodd
# ID: 1265, Name: Verile Doghartie
# ID: 1266, Name: Michale Domleo
# ID: 1267, Name: Curran Donneely
# ID: 1268, Name: Arin Donson
# ID: 1269, Name: Garvey Doohan
# ID: 1270, Name: Shellie Dootson
# ID: 1271, Name: Jasmin Dorie
# ID: 1272, Name: Ashly Dotterill
# ID: 1273, Name: Lorry Dowdell
# ID: 1274, Name: Lenee Dowtry
# ID: 1275, Name: Trevor Dracey
# ID: 1276, Name: Amandi Drakers
# ID: 1277, Name: Abagael Draude
# ID: 1278, Name: Ddene Drugan
# ID: 1280, Name: Zoe Ducker
# ID: 1281, Name: Ellerey Dudenie
# ID: 1282, Name: Maudie Dudhill
# ID: 1283, Name: Betti Duggan
# ID: 1284, Name: Sile Duigan
# ID: 1285, Name: Ardeen Dulwitch
# ID: 1286, Name: Frances Dulwitch
# ID: 1287, Name: Dniren Dundin
# ID: 1288, Name: Katerine Dungay
# ID: 1289, Name: Hetti Dungay
# ID: 1290, Name: Cassandre Dunne
# ID: 1291, Name: Chuck Dunniom
# ID: 1292, Name: Brice Duplain
# ID: 1293, Name: Arvie Dyhouse
# ID: 1294, Name: Claretta Dymond
# ID: 1295, Name: Marylou Dytham
# ID: 1296, Name: Alfred Eadmeades
# ID: 1297, Name: Jarvis Ealden
# ID: 1298, Name: Chrysler Eardley
# ID: 1299, Name: Jerrilee Eastop
# ID: 1300, Name: Saidee Eate
# ID: 1301, Name: Anders Edmeades
# ID: 1302, Name: Arlene Edmonston
# ID: 1303, Name: Hillary Egan
# ID: 1305, Name: Waneta Elfitt
# ID: 1306, Name: Norby Elington
# ID: 1307, Name: Danell Ellam
# ID: 1308, Name: Rodrigo Elphinstone
# ID: 1309, Name: Aleen Emps
# ID: 1310, Name: Revkah Erdis
# ID: 1311, Name: Ursulina Erie
# ID: 1312, Name: Valma Erwin
# ID: 1313, Name: Roberta Etches
# ID: 1314, Name: Luciano Etherson
# ID: 1315, Name: Beverie Ettels
# ID: 1316, Name: Tades Facey
# ID: 1317, Name: Cammy Fader
# ID: 1318, Name: Mimi Fake
# ID: 1319, Name: Wilt Fakeley
# ID: 1320, Name: Artemas Farbrace
# ID: 1321, Name: Darleen Farndell
# ID: 1322, Name:
# ID: 1324, Name: Janna Fearnehough
# ID: 1325, Name: Abe Featherby
# ID: 1326, Name: Carlota Feavers
# ID: 1327, Name: Kevina Feechum
# ID: 1328, Name: Grace Felderer
# ID: 1329, Name: Gale Fendt
# ID: 1330, Name: Timotheus Ferdinand
# ID: 1331, Name: Darleen Fereday
# ID: 1332, Name: Nancey Ferrettini
# ID: 1333, Name: Margot Ferroli
# ID: 1334, Name: Tina Fetherstone
# ID: 1335, Name: Arline Fiddler
# ID: 1336, Name: Morissa Fifoot
# ID: 1337, Name: Rosemarie Fleay
# ID: 1338, Name: Ravid Flemmich
# ID: 1339, Name: Penelopa Flewett
# ID: 1340, Name: Thom Flips
# ID: 1341, Name: Bordy Flynn
# ID: 1342, Name: Nathanil Foker
# ID: 1343, Name: Celestina Folca
# ID: 1344, Name: Christen Folkerts
# ID: 1345, Name: Corenda Folomin
# ID: 1346, Name: Iris Ford
# ID: 1347, Name: Sumner Forgie
# ID: 1348, Name: Benny Forsey
# ID: 1349, Name: Winona Forst
# ID: 1350, Name: Gilda Fowlestone
# ID: 1351, Name: Weston Foxton
# ID: 1352, Name: Eunice Francillo
# ID: 1353, Name: Raul Franke
# ID: 1354, Name: Cobby Frankiss
# ID: 1355, Name: Carina Franzini
# ID: 1356, Name: Johnnie Frary
# ID: 1357, Name: Jocelyne Frary
# ID: 1358, Name: Kaycee Frazier
# ID: 1359, Name: Justine Freeborn
# ID: 1360, Name: Killy Friary
# ID: 1361, Name: Ike Friman
# ID: 1362, Name: Melodee Froude
# ID: 1363, Name: Cassi Frudd
# ID: 1364, Name: Ora Fryman
# ID: 1365, Name: Fredelia Fucher
# ID: 1366, Name: Renee Fuggle
# ID: 1367, Name: Ellary Fulmen
# ID: 1368, Name: Rustie Fumagallo
# ID: 1369, Name: Jennifer Furlow
# ID: 1370, Name: Luciana Gages
# ID: 1371, Name: King Gallelli
# ID: 1372, Name: Gabriele Galpen
# ID: 1373, Name: Leisha Gamlen
# ID: 1374, Name: Far Gannicott
# ID: 1375, Name: Tracey Gare
# ID: 1376, Name: Gwenore Garm
# ID: 1377, Name: Guendolen Garoghan
# ID: 1378, Name: Toni Garriock
# ID: 1379, Name: Ruth Gatch
# ID: 1380, Name: Grantley Gauvin
# ID: 1381, Name: Stormi Gawthrop
# ID: 1382, Name: Bowie Geaveny
# ID: 1383, Name: Emmott Geraldez
# ID: 1384, Name: Milicent Giacobo
# ID: 1385, Name: Francine Gilbane
# ID: 1386, Name: Hattie Gilder
# ID: 1387, Name: Dex Gilham
# ID: 1388, Name: Bo Gillmore
# ID: 1389, Name: Emmalynne Ginley
# ID: 1390, Name: Harp Giovanitti
# ID: 1391, Name: Rania Giovanizio
# ID: 1392, Name: Cris Gladdis
# ID: 1393, Name: Bogey Gladtbach
# ID: 1394, Name: Latrena Glasscock
# ID: 1395, Name: Saidee Glew
# ID: 1396, Name: Melisandra Gligoraci
# ID: 1397, Name: Lefty Glusby
# ID: 1398, Name: Kaitlin Goodge
# ID: 1399, Name: Brose Goodwins
# ID: 1400, Name: Babita Gore
# ID: 1401, Name: Kori Gorman
# ID: 1402, Name: Hasty Gottelier
# ID: 1403, Name: Fergus Goudy
# ID: 1404, Name: Chet Goves
# ID: 1405, Name: Reyna Gowrie
# ID: 1406, Name: Isador Greatham
# ID: 1407, Name: Doris Greenman
# ID: 1408, Name: Bonnibelle Greenway
# ID: 1409, Name: Annabela Greeve
# ID: 1410, Name: Vally Greste
# ID: 1411, Name: Dominic Gridon
# ID: 1412, Name: Anna Griffey
# ID: 1414, Name: Anderea Grisard
# ID: 1415, Name: Kari Grishechkin
# ID: 1416, Name: Jacquette Grumell
# ID: 1417, Name: Jeannette Grundey
# ID: 1418, Name: Gilberta Gudgin
# ID: 1419, Name: Hayward Gunton
# ID: 1420, Name: Devon Habberjam
# ID: 1421, Name: Merna Haddock
# ID: 1422, Name: Monika Hadkins
# ID: 1424, Name: Jeana Hadlow
# ID: 1425, Name: Brenn Hadye
# ID: 1426, Name: Trumaine Halburton
# ID: 1427, Name: Tara Halfhead
# ID: 1428, Name: Kristofor Hallewell
# ID: 1429, Name: Ashbey Halliburton
# ID: 1430, Name: Zed Hallowes
# ID: 1431, Name: Vyky Hammerberger
# ID: 1433, Name: Aarika Hantusch
# ID: 1434, Name: Bernadina Hanwell
# ID: 1435, Name: Eleanora Haquin
# ID: 1436, Name: Chanda Hastilow
# ID: 1437, Name: Alwin Haugen
# ID: 1438, Name: Nanine Haverson
# ID: 1439, Name: Florie Haxby
# ID: 1440, Name: Oren Hayball
# ID: 1441, Name: Irwin Haylett
# ID: 1442, Name: Hale Headings
# ID: 1443, Name: Cherey Heazel
# ID: 1444, Name: Jacenta Hegden
# ID: 1445, Name: Gilles Heino
# ID: 1446, Name: Risa Heinrici
# ID: 1447, Name: Midge Held
# ID: 1448, Name: Greg Hellmore
# ID: 1449, Name: Emory Helmke
# ID: 1450, Name: Loise Hembling
# ID: 1451, Name: Avrit Hendonson
# ID: 1452, Name: Truman Henniger
# ID: 1453, Name: Liz Henrichsen
# ID: 1454, Name: Gilda Heritege
# ID: 1455, Name: Rodge Hernik
# ID: 1456, Name: Rivi Hiley
# ID: 1457, Name: Marcelline Hillaby
# ID: 1458, Name: Norean Hobbing
# ID: 1459, Name: Maisey Hobgen
# ID: 1460, Name: Melva Hofer
# ID: 1461, Name: Alfi Holberry
# ID: 1462, Name: Correna Horsfield
# ID: 1464, Name: Fanchette Hounsom
# ID: 1465, Name: Hamnet Hubane
# ID: 1466, Name: Chandler Huby
# ID: 1468, Name: Leela Hurd
# ID: 1469, Name: Shelby Hurlin
# ID: 1470, Name: Lianne Huxton
# ID: 1471, Name: Ethelda Iacomi
# ID: 1472, Name: Payton Iacopini
# ID: 1473, Name: Berk Iacovelli
# ID: 1475, Name: Lebbie Ibanez
# ID: 1476, Name: Friedrich Ilyas
# ID: 1477, Name: Loella Ilyinykh
# ID: 1478, Name: Tersina Inchbald
# ID: 1479, Name: Doria Ingleson
# ID: 1480, Name: Brena Ingrem
# ID: 1481, Name: Eileen Ireland
# ID: 1482, Name: Emmalynn Issatt
# ID: 1484, Name: Arlene Jack
# ID: 1485, Name: Hill Jagoe
# ID: 1486, Name: Joanie Jahner
# ID: 1487, Name: Fanechka Jakubczyk
# ID: 1488, Name: Samantha James
# ID: 1489, Name: Arabelle Jamson
# ID: 1490, Name: Mathew Janczak
# ID: 1491, Name: Liane Janicek
# ID: 1492, Name: Lesya Janjusevic
# ID: 1493, Name:
# ID: 1494, Name: Fredericka Jarmain
# ID: 1495, Name: Seth Jeffree
# ID: 1496, Name: Carissa Jeffrey
# ID: 1497, Name: Teddi Jeffrey
# ID: 1498, Name: Teriann Jell
# ID: 1499, Name: Holly Jellard
# ID: 1500, Name: Audrye Jendrys
# ID: 1501, Name: Adaline Jephcote
# ID: 1502, Name: Myrtle Johanning
# ID: 1503, Name: Anjanette Johansson
# ID: 1504, Name: Avrit Jopling
# ID: 1505, Name: Andi Josey
# ID: 1506, Name: Joye Josse
# ID: 1507, Name: Nonie Josuweit
# ID: 1508, Name: Tommy Jouannisson
# ID: 1509, Name: Tiphanie Joyce
# ID: 1510, Name: Zelda Juara
# ID: 1511, Name: Cecilia Julien
# ID: 1512, Name: Malia Juszczak
# ID: 1513, Name: Garald Kaes
# ID: 1514, Name: Francis Kamenar
# ID: 1515, Name: Stephenie Karolowski
# ID: 1516, Name: Kerry Keatley
# ID: 1517, Name: Falito Keepe
# ID: 1518, Name: Cassandra Kellegher
# ID: 1519, Name: Perkin Kelson
# ID: 1520, Name: Kial Kemer
# ID: 1521, Name: Paulita Kemet
# ID: 1522, Name: Gina Kenan
# ID: 1524, Name: Jacenta Kender
# ID: 1525, Name: Maiga Kenningley
# ID: 1526, Name: Vivie Kensitt
# ID: 1527, Name: Maxy Kerner
# ID: 1528, Name: Doyle Kettlestringes
# ID: 1529, Name: Deena Kew
# ID: 1530, Name: Jacques Keynd
# ID: 1531, Name: Daune Kid
# ID: 1532, Name: Alfreda Kiddye
# ID: 1533, Name: Tiertza Killingworth
# ID: 1534, Name: Rex Kinghorne
# ID: 1535, Name: Jorry Kinig
# ID: 1536, Name: Mellicent Kinnard
# ID: 1537, Name: Marya Kirman
# ID: 1538, Name: Rafferty Kleinhaus
# ID: 1539, Name: Grace Klimaszewski
# ID: 1540, Name: Chrysler Kobera
# ID: 1541, Name: Jennie Kopje
# ID: 1542, Name: Dewie Koppel
# ID: 1543, Name: Melodie Kordt
# ID: 1544, Name: Curr Kropp
# ID: 1545, Name: Allan Kruger
# ID: 1546, Name: Zack Kubacek
# ID: 1547, Name: Kirsteni Kubicki
# ID: 1548, Name: Pegeen Lafrentz
# ID: 1549, Name: Antonina Lakeland
# ID: 1550, Name: Ellene Lamperd
# ID: 1551, Name: Lind Landrick
# ID: 1552, Name: Quintus Lawden
# ID: 1553, Name: Bobette Lawlan
# ID: 1554, Name: Eziechiele Lawton
# ID: 1555, Name: Annabella Le Floch
# ID: 1556, Name: Giff Leaning
# ID: 1557, Name: Kamila Leate
# ID: 1558, Name: Avivah Leber
# ID: 1559, Name: Woodman Leeds
# ID: 1560, Name: Zena Lees
# ID: 1562, Name: Letisha Leicester
# ID: 1563, Name: Sharona Leipelt
# ID: 1564, Name: Pietro Lemmertz
# ID: 1565, Name: Karen Leversha
# ID: 1566, Name: Ingrim Libreros
# ID: 1567, Name: Annabelle Liddel
# ID: 1568, Name: Jody Liffey
# ID: 1569, Name: Newton Liggins
# ID: 1570, Name: Cati Limpenny
# ID: 1571, Name: Saraann Lindenberg
# ID: 1572, Name: Bethena Lindenstrauss
# ID: 1573, Name: Hynda Lippiello
# ID: 1574, Name: Laura Liversedge
# ID: 1575, Name: Edgard Lopez
# ID: 1576, Name: Noak Lording
# ID: 1577, Name: Kenneth Lorey
# ID: 1578, Name: Garfield Loton
# ID: 1579, Name: Deane Lovemore
# ID: 1580, Name: Eugenio Low
# ID: 1581, Name: Gris Loxton
# ID: 1582, Name: Adams Luisetti
# ID: 1583, Name: Chrotoem Lunam
# ID: 1584, Name: Renado Lyne
# ID: 1585, Name: Sonja MacAllen
# ID: 1586, Name: Roanne MacColl
# ID: 1587, Name: Deina MacFaell
# ID: 1588, Name: Gabriell MacGebenay
# ID: 1591, Name: Antonia MacLice
# ID: 1592, Name: Anni MacMakin
# ID: 1593, Name: Ruthi MacTavish
# ID: 1594, Name: Vinny Magovern
# ID: 1595, Name: Charita Magrane
# ID: 1596, Name: Noble Magson
# ID: 1597, Name: Rahal Malitrott
# ID: 1598, Name: Hope Malkinson
# ID: 1599, Name: Chrystal Maloney
# ID: 1600, Name: Niels Malt
# ID: 1601, Name: Vincents Marciek
# ID: 1602, Name: Gamaliel Markie
# ID: 1603, Name: Zulema Markus
# ID: 1604, Name: Trace Marshal
# ID: 1605, Name: Matteo Martensen
# ID: 1606, Name: Mitzi Martinetto
# ID: 1607, Name: Inglis Masding
# ID: 1608, Name: Rita Massimo
# ID: 1609, Name: Doyle Matei
# ID: 1610, Name: Andreas Mathis
# ID: 1611, Name: Hill Matterdace
# ID: 1612, Name: Jazmin Mattiato
# ID: 1614, Name: Shawn Maun
# ID: 1615, Name: Jillana Mayze
# ID: 1616, Name: Emlen McAless
# ID: 1617, Name: Valenka McCaghan
# ID: 1618, Name: Hasheem McCahill
# ID: 1619, Name: Karlene McCallister
# ID: 1620, Name: Cilka McCory
# ID: 1621, Name: Sheri McCoveney
# ID: 1622, Name: Dodie McCrae
# ID: 1623, Name: Hubert McCraw
# ID: 1624, Name: Stearne McCudden
# ID: 1625, Name: Toddy McFee
# ID: 1626, Name: Maribeth McGiffie
# ID: 1627, Name: Deanne McHarry
# ID: 1628, Name: Adan McMurray
# ID: 1629, Name: Goldia McNirlan
# ID: 1630, Name: Adler McPhillips
# ID: 1631, Name: Yettie McRobert
# ID: 1632, Name: Loree Mendez
# ID: 1633, Name: Charline Meran
# ID: 1634, Name: Duff Mertel
# ID: 1635, Name: Winne Mewton
# ID: 1636, Name: Adair Middle
# ID: 1637, Name: Serena Milburne
# ID: 1638, Name: Revkah Miles
# ID: 1639, Name: Candis Millam
# ID: 1640, Name: Auguste Minards
# ID: 1641, Name: Muffin Monahan
# ID: 1642, Name: Ronda Montel
# ID: 1643, Name: Andi Morcomb
# ID: 1644, Name: Bjorn Morican
# ID: 1645, Name: Hedvige Morter
# ID: 1646, Name: Shelagh Mossman
# ID: 1647, Name: Flori Mowatt
# ID: 1648, Name: August Mower
# ID: 1649, Name: Karina Mowett
# ID: 1650, Name: Callida Mulcock
# ID: 1651, Name: Shirlee Muldrew
# ID: 1652, Name: Corabel Muncie
# ID: 1653, Name: Catlee Mundie
# ID: 1654, Name: Gloria Muzzini
# ID: 1655, Name: Juliette Myrick
# ID: 1656, Name: Fayina Nalder
# ID: 1657, Name: Gawen Narraway
# ID: 1658, Name: Valeria Nasi
# ID: 1659, Name: Tailor Natte
# ID: 1660, Name: Beaufort Navarre
# ID: 1661, Name: Winnie Nayer
# ID: 1662, Name: Ingunna Neads
# ID: 1663, Name: Catha Neeson
# ID: 1664, Name: Meara Neggrini
# ID: 1665, Name: Noah Neno
# ID: 1666, Name: Rad Nickols
# ID: 1667, Name: Jinny Nissle
# ID: 1668, Name: Larry Nobes
# ID: 1669, Name: Shannan Nolleau
# ID: 1670, Name: Cordelia Nolton
# ID: 1671, Name: Ernaline Norcutt
# ID: 1672, Name: Windham Northcote
# ID: 1673, Name: Cosette Norwich
# ID: 1674, Name: Marita Norwood
# ID: 1675, Name: Roxanna Novis
# ID: 1676, Name: My Nucciotti
# ID: 1677, Name: Karel Nutty
# ID: 1678, Name: Rhonda O'Boyle
# ID: 1679, Name: Aguste O'Cridigan
# ID: 1680, Name: Werner O'Farrell
# ID: 1681, Name: Janek O'Garmen
# ID: 1682, Name: Noemi O'Hingerty
# ID: 1683, Name: Fidel O'Keefe
# ID: 1684, Name: D'arcy O'Kinneally
# ID: 1685, Name: Bruno O'Leahy
# ID: 1687, Name: Evaleen Obin
# ID: 1688, Name:
# ID: 1689, Name: Jacquelin Ofen
# ID: 1690, Name: Sarene Ogdahl
# ID: 1691, Name: Benedetto Olczyk
# ID: 1692, Name: Algernon Oldall
# ID: 1693, Name: Rebeca Oldred
# ID: 1694, Name: Fergus Oleszcuk
# ID: 1695, Name: Gillan Ollivierre
# ID: 1696, Name: Evered Oluwatoyin
# ID: 1697, Name: Sumner Omand
# ID: 1698, Name: Daloris Oneal
# ID: 1699, Name: Nettle Opdenorth
# ID: 1700, Name: Amos Orbell
# ID: 1701, Name: Clarie Ordemann
# ID: 1702, Name: Ettore Orgel
# ID: 1703, Name: Ahmed Orrum
# ID: 1704, Name: Linell Ort
# ID: 1705, Name: Bonita Ortiga
# ID: 1706, Name: Valentina Oslar
# ID: 1707, Name: Berty Osmar
# ID: 1708, Name: Charles Ostridge
# ID: 1709, Name: Nev Ough
# ID: 1710, Name: Augusto Oulett
# ID: 1711, Name: Andra Owbrick
# ID: 1712, Name: Cathrin Paffitt
# ID: 1713, Name: Isa Pagelsen
# ID: 1715, Name: Isobel Pallaske
# ID: 1716, Name: Evered Palmer
# ID: 1717, Name: Marcelo Parramore
# ID: 1718, Name: Berty Parren
# ID: 1719, Name: Delmer Pash
# ID: 1720, Name: Shaine Pauel
# ID: 1721, Name: Marge Paulisch
# ID: 1722, Name: Cherilynn Paull
# ID: 1723, Name: Alexandrina Pavlenko
# ID: 1724, Name: Bliss Pedrozzi
# ID: 1725, Name: Tomas Peele
# ID: 1726, Name: Leigh Penhallurick
# ID: 1727, Name: Raynor Peniello
# ID: 1728, Name: Kelwin Pennings
# ID: 1729, Name: Milty Pennings
# ID: 1730, Name: Rodolphe Peschka
# ID: 1731, Name: Maynord Pester
# ID: 1732, Name: Cyrille Pettipher
# ID: 1733, Name: Parsifal Pevreal
# ID: 1734, Name: Rock Pezey
# ID: 1735, Name: Chrissie Philbin
# ID: 1736, Name: Chalmers Phillipp
# ID: 1737, Name: Kissiah Phizakarley
# ID: 1738, Name: Ettore Piccard
# ID: 1739, Name: Rafael Pickering
# ID: 1740, Name: Jonie Pieterick
# ID: 1741, Name: Malachi Pietroni
# ID: 1742, Name: Wadsworth Pigeon
# ID: 1743, Name: Georg Pigney
# ID: 1744, Name: Jilli Pilcher
# ID: 1745, Name: Mickie Piletic
# ID: 1746, Name: Lorette Pinson
# ID: 1747, Name: Lettie Pires
# ID: 1748, Name: Indira Pirozzi
# ID: 1749, Name: Roseanne Pitkeathley
# ID: 1750, Name: Alidia Playden
# ID: 1751, Name: Zarah Plott
# ID: 1752, Name: Dennet Plumridge
# ID: 1753, Name: Victoria Pontain
# ID: 1754, Name: Aldis Pottes
# ID: 1755, Name: Cass Poynser
# ID: 1756, Name: Rickie Prati
# ID: 1757, Name: Patrizio Presswell
# ID: 1758, Name: Dyanne Prestney
# ID: 1759, Name: Stern Prichard
# ID: 1760, Name: Giuditta Prince
# ID: 1761, Name: Adi Priscott
# ID: 1762, Name: Frank Prop
# ID: 1763, Name: Rozella Purvess
# ID: 1764, Name: Nancee Pybus
# ID: 1765, Name: Rosemary Pyson
# ID: 1766, Name: Constantina Queste
# ID: 1767, Name: Heinrik Rae
# ID: 1768, Name: Moises Rainy
# ID: 1769, Name: Alena Raison
# ID: 1770, Name: Ally Rakes
# ID: 1771, Name: Theo Ralston
# ID: 1772, Name: Loralyn Ramsden
# ID: 1773, Name: Eloisa Rannald
# ID: 1774, Name: Agata Raspison
# ID: 1775, Name: Clarice Ravenscroftt
# ID: 1776, Name: Cele Rayne
# ID: 1777, Name: Milo Reach
# ID: 1778, Name: Ross Reardon
# ID: 1779, Name: Darwin Reaveley
# ID: 1781, Name: Junina Rembaud
# ID: 1782, Name: Risa Revance
# ID: 1783, Name: Herve Ribeiro
# ID: 1784, Name: Selby Ribeiro
# ID: 1785, Name: Torey Richardin
# ID: 1786, Name: Virgie Rickert
# ID: 1787, Name: Flossi Rillett
# ID: 1788, Name: Christie Rilston
# ID: 1789, Name: Jennine Rilton
# ID: 1790, Name: Emmie Rippingale
# ID: 1791, Name: Theda Rittelmeyer
# ID: 1792, Name: Hetty Robilliard
# ID: 1793, Name: Shanna Robion
# ID: 1794, Name: Loise Romei
# ID: 1795, Name: Bonny Ropking
# ID: 1796, Name: Roxane Roswarn
# ID: 1797, Name: Rudie Rouchy
# ID: 1798, Name: Bridie Rowan
# ID: 1799, Name:
# ID: 1800, Name: Karylin Rubinivitz
# ID: 1801, Name: Ursala Rubinsohn
# ID: 1802, Name: Kelley Rudolfer
# ID: 1803, Name: Vivyanne Ruit
# ID: 1804, Name: Gracia Ruit
# ID: 1805, Name: Rudie Rusted
# ID: 1806, Name: Barth Rutter
# ID: 1807, Name: Emmet Rycroft
# ID: 1808, Name: Electra Sabbins
# ID: 1809, Name: Krishnah Sacher
# ID: 1810, Name: Lia Saenz
# ID: 1811, Name: Georgeanna Saggs
# ID: 1812, Name: Izzy Saintpierre
# ID: 1813, Name: Betty Sambiedge
# ID: 1815, Name: Lucian Samter
# ID: 1816, Name: Caralie Sapseed
# ID: 1817, Name: Virge Sarver
# ID: 1818, Name: Yancy Savaage
# ID: 1819, Name: Winnah Savage
# ID: 1820, Name: Myrna Sawden
# ID: 1821, Name: Lindsay Sayre
# ID: 1822, Name: Ericha Schapero
# ID: 1823, Name: Barr Schindler
# ID: 1824, Name: Kaitlynn Schleswig-Holstein
# ID: 1825, Name: Daisi Schwartz
# ID: 1826, Name: Holly Scoffins
# ID: 1827, Name: Opalina Scopyn
# ID: 1828, Name: Rickey Scotsbrook
# ID: 1829, Name: Cory Scragg
# ID: 1830, Name: Charla Scroxton
# ID: 1831, Name: Christabella Searby
# ID: 1832, Name: Letta Search
# ID: 1833, Name: Essa Seddon
# ID: 1834, Name: Kurtis Semarke
# ID: 1835, Name: Coleman Semble
# ID: 1836, Name: Jorgan Semechik
# ID: 1837, Name: Wilton Serridge
# ID: 1838, Name: Sheeree Seston
# ID: 1839, Name: Camille Seymour
# ID: 1840, Name: Haily Shackelton
# ID: 1841, Name: Burlie Shakespeare
# ID: 1842, Name: Lelah Shaughnessy
# ID: 1843, Name: Julio Sheavills
# ID: 1844, Name: Agnesse Sheber
# ID: 1845, Name: Knox Sherbrooke
# ID: 1846, Name: Rouvin Sherrett
# ID: 1847, Name: Myrtia Shervington
# ID: 1848, Name: Randolph Shorbrook
# ID: 1849, Name: Melina Shotter
# ID: 1850, Name: Chryste Sibylla
# ID: 1851, Name: Karna Sigward
# ID: 1852, Name: Titus Sikorski
# ID: 1853, Name: Meryl Sillick
# ID: 1854, Name: Normie Simcock
# ID: 1855, Name: Hanna Simek
# ID: 1856, Name: Quinta Simonds
# ID: 1857, Name: Joyann Simonnin
# ID: 1858, Name:
# ID: 1859, Name: Saree Skaif
# ID: 1861, Name: Ferdinanda Slocomb
# ID: 1862, Name: Yoko Sloegrave
# ID: 1863, Name: Rafferty Smalls
# ID: 1864, Name: Alane Smither
# ID: 1865, Name: Sebastian Smithin
# ID: 1866, Name: Nessie Snepp
# ID: 1867, Name: Betsey Sockell
# ID: 1868, Name: Josefina Sofe
# ID: 1870, Name: Baldwin Sommerlin
# ID: 1871, Name: Toiboid Southon
# ID: 1872, Name: Hedwig Sowrah
# ID: 1873, Name: Aldous Spadelli
# ID: 1874, Name: Lorettalorna Spellessy
# ID: 1875, Name: Florencia Spence
# ID: 1876, Name: Ignacio Spence
# ID: 1877, Name: Tadio Spere
# ID: 1878, Name: Billie Spikeings
# ID: 1879, Name: Waylin Sponer
# ID: 1880, Name: Lotti Spyer
# ID: 1881, Name: Frederich Sreenan
# ID: 1882, Name: Carleen Stafford
# ID: 1883, Name: Batholomew Stammirs
# ID: 1884, Name: Joey Stebbing
# ID: 1885, Name: Lorne Stennes
# ID: 1886, Name: Judy Sterzaker
# ID: 1887, Name: Trudey Stickells
# ID: 1888, Name: Willetta Stirtle
# ID: 1889, Name: Sibylla Stittle
# ID: 1890, Name: Carlina Stivani
# ID: 1891, Name: Brandy Stoad
# ID: 1892, Name: Thedrick Stock
# ID: 1893, Name: Nertie Stoddard
# ID: 1894, Name: Catina Stops
# ID: 1895, Name: Adela Storms
# ID: 1896, Name: Mata Streatfeild
# ID: 1897, Name: Pasquale Stroton
# ID: 1898, Name: Amye Stroulger
# ID: 1899, Name: Helen-elizabeth Suckling
# ID: 1900, Name: Darb Summersett
# ID: 1901, Name: Hyacinthie Sushams
# ID: 1902, Name: Diandra Swainsbury
# ID: 1903, Name: Carolyn Sweed
# ID: 1904, Name: Roi Swigger
# ID: 1905, Name: Lib Swinden
# ID: 1906, Name: Currie Syder
# ID: 1907, Name: Maurizio Symons
# ID: 1908, Name: Roxy Syne
# ID: 1909, Name: Zebedee Szymanzyk
# ID: 1910, Name: Bar Taggert
# ID: 1911, Name: Darill Tant
# ID: 1912, Name: Ottilie Tapply
# ID: 1913, Name: Moll Tasch
# ID: 1914, Name: Freeman Telezhkin
# ID: 1915, Name: Hyatt Tellenbrok
# ID: 1916, Name: Nanon Temblett
# ID: 1917, Name: Gaby Terne
# ID: 1918, Name: Brooke Thornbarrow
# ID: 1919, Name: Bobbie Threadgould
# ID: 1920, Name: Herculie Thrush
# ID: 1921, Name: Dion Tilburn
# ID: 1922, Name: Vincents Tillot
# ID: 1923, Name: Gill Tomasek
# ID: 1924, Name: Brunhilde Toogood
# ID: 1926, Name: Kath Tott
# ID: 1927, Name: Lamond Trevarthen
# ID: 1928, Name: Leroi Trump
# ID: 1929, Name: Antonin Truter
# ID: 1930, Name: Jorrie Trytsman
# ID: 1931, Name: Wilhelmine Tully
# ID: 1932, Name: Celeste Tures
# ID: 1933, Name: Albrecht Tweedy
# ID: 1934, Name: Spence Twinbourne
# ID: 1935, Name: Noelle Tythacott
# ID: 1936, Name: Nelly Tzarkov
# ID: 1937, Name: Rikki Uccelli
# ID: 1938, Name: Gillie Ulyatt
# ID: 1939, Name: Keeley Ungaretti
# ID: 1940, Name: Klara Valeri
# ID: 1941, Name: Jennee Van der Merwe
# ID: 1942, Name: Joaquin Vanyashin
# ID: 1943, Name: Samson Vasishchev
# ID: 1944, Name: Rhonda Vasnetsov
# ID: 1945, Name: Lavinie Vearncomb
# ID: 1946, Name: Ellsworth Veasey
# ID: 1947, Name: Paton Veazey
# ID: 1948, Name: Alexandre Vedyasov
# ID: 1949, Name: Guinevere Vedyasov
# ID: 1950, Name: Devy Verny
# ID: 1951, Name: Beaufort Verny
# ID: 1952, Name: Krisha Vero
# ID: 1953, Name: Garwood Verralls
# ID: 1954, Name: Vevay Vice
# ID: 1955, Name: Shena Vinall
# ID: 1956, Name: Brena Vogelein
# ID: 1957, Name: Jud Vogt
# ID: 1958, Name: Esdras Voysey
# ID: 1959, Name: Marylinda Wakeman
# ID: 1960, Name: Daphene Walkey
# ID: 1961, Name: Lionello Walthall
# ID: 1962, Name: Guinna Walworche
# ID: 1963, Name: Stevie Wapol
# ID: 1964, Name: Baldwin Warlowe
# ID: 1965, Name: Lita Watkiss
# ID: 1966, Name: Gertrud Weaben
# ID: 1967, Name: Jessee Welbeck
# ID: 1968, Name: Gunar Wheatcroft
# ID: 1969, Name: Dulcea Whinray
# ID: 1970, Name: Eadith Whitington
# ID: 1971, Name: Katherina Whitton
# ID: 1972, Name: Bridgette Wickey
# ID: 1973, Name: Stanleigh Willans
# ID: 1974, Name: Hewet Willarton
# ID: 1975, Name: Gina Wilton
# ID: 1976, Name: Gerrard Windmill
# ID: 1977, Name: Tremain Withnall
# ID: 1978, Name: Harwilll Wogden
# ID: 1979, Name: Marney Wolfart
# ID: 1980, Name: Crystal Wollen
# ID: 1981, Name: Hadlee Woodard
# ID: 1982, Name: Kermy Woofinden
# ID: 1983, Name: Felicia Wooldridge
# ID: 1984, Name: Violette Woollin
# ID: 1985, Name: Erena Wornum
# ID: 1986, Name: Starla Wreiford
# ID: 1988, Name: Danya Wyre
# ID: 1989, Name: Sherrie Yakovliv
# ID: 1990, Name: Claudian Yandell
# ID: 1991, Name: Alissa Yanukhin
# ID: 1992, Name: Tad Yatman
# ID: 1993, Name: Maggy Yaus
# ID: 1994, Name: Hedi Yeowell
# ID: 1995, Name: Goran Yong
# ID: 1996, Name: Cirstoforo Youings
# ID: 1997, Name: Wilek Yurkevich
# ID: 1998, Name: Jerry Yven
# ID: 1999, Name: Jerri Zebedee

# %%
# Test loaded data with SQL
sql_query = text("SELECT * FROM jobs")
result = session.execute(sql_query)
resultados = result.fetchall()

# Print the rows
print("\nJobs:")
for r in resultados:
    print(f"ID: {r.id}, Job: {r.job}")
# Out:
# Jobs:
# ID: 1, Job: Marketing Assistant
# ID: 2, Job: VP Sales
# ID: 3, Job: Biostatistician IV
# ID: 4, Job: Account Representative II
# ID: 5, Job: VP Marketing
# ID: 6, Job: Environmental Specialist
# ID: 7, Job: Software Consultant
# ID: 8, Job: Office Assistant III
# ID: 9, Job: Information Systems Manager
# ID: 10, Job: Desktop Support Technician
# ID: 11, Job: Financial Advisor
# ID: 12, Job: Computer Systems Analyst I
# ID: 13, Job: Automation Specialist IV
# ID: 14, Job: Help Desk Technician
# ID: 15, Job: Office Assistant II
# ID: 16, Job: VP Quality Control
# ID: 17, Job: Office Assistant IV
# ID: 18, Job: Financial Analyst
# ID: 19, Job: Electrical Engineer
# ID: 20, Job: Chemical Engineer
# ID: 21, Job: Social Worker
# ID: 22, Job: VP Product Management
# ID: 23, Job: Administrative Officer
# ID: 24, Job: Paralegal
# ID: 25, Job: Actuary
# ID: 26, Job: Database Administrator I
# ID: 27, Job: Nuclear Power Engineer
# ID: 28, Job: Database Administrator II
# ID: 29, Job: GIS Technical Architect
# ID: 30, Job: Human Resources Assistant IV
# ID: 31, Job: Marketing Manager
# ID: 32, Job: Structural Engineer
# ID: 33, Job: General Manager
# ID: 34, Job: Chief Design Engineer
# ID: 35, Job: Senior Quality Engineer
# ID: 36, Job: Pharmacist
# ID: 37, Job: Accounting Assistant IV
# ID: 38, Job: Web Developer I
# ID: 39, Job: Automation Specialist I
# ID: 40, Job: Assistant Manager
# ID: 41, Job: Director of Sales
# ID: 42, Job: Systems Administrator II
# ID: 43, Job: Geological Engineer
# ID: 44, Job: Staff Accountant IV
# ID: 45, Job: Senior Cost Accountant
# ID: 46, Job: Geologist IV
# ID: 47, Job: Graphic Designer
# ID: 48, Job: Account Executive
# ID: 49, Job: Staff Scientist
# ID: 50, Job: VP Accounting
# ID: 51, Job: Quality Control Specialist
# ID: 52, Job: Structural Analysis Engineer
# ID: 53, Job: Food Chemist
# ID: 54, Job: Systems Administrator IV
# ID: 55, Job: Software Test Engineer IV
# ID: 56, Job: Analyst Programmer
# ID: 57, Job: Clinical Specialist
# ID: 58, Job: Teacher
# ID: 59, Job: Budget/Accounting Analyst IV
# ID: 60, Job: Recruiter
# ID: 61, Job: Geologist II
# ID: 62, Job: Associate Professor
# ID: 63, Job: Executive Secretary
# ID: 64, Job: Senior Editor
# ID: 65, Job: Civil Engineer
# ID: 66, Job: Junior Executive
# ID: 67, Job: Senior Financial Analyst
# ID: 68, Job: Programmer IV
# ID: 69, Job: Biostatistician III
# ID: 70, Job: Dental Hygienist
# ID: 71, Job: Statistician II
# ID: 72, Job: Web Designer I
# ID: 73, Job: Sales Representative
# ID: 74, Job: Engineer III
# ID: 75, Job: Community Outreach Specialist
# ID: 76, Job: Budget/Accounting Analyst III
# ID: 77, Job: Database Administrator III
# ID: 78, Job: Recruiting Manager
# ID: 79, Job: Programmer III
# ID: 80, Job: Quality Engineer
# ID: 81, Job: Health Coach IV
# ID: 82, Job: Assistant Professor
# ID: 83, Job: Cost Accountant
# ID: 84, Job: Software Engineer I
# ID: 85, Job: Research Assistant II
# ID: 86, Job: Research Assistant IV
# ID: 87, Job: Accountant I
# ID: 88, Job: Accountant IV
# ID: 89, Job: Account Representative IV
# ID: 90, Job: Computer Systems Analyst IV
# ID: 91, Job: Product Engineer
# ID: 92, Job: Account Coordinator
# ID: 93, Job: Engineer IV
# ID: 94, Job: Software Engineer III
# ID: 95, Job: Web Designer II
# ID: 96, Job: Health Coach III
# ID: 97, Job: Media Manager III
# ID: 98, Job: Librarian
# ID: 99, Job: Environmental Tech
# ID: 100, Job: Senior Developer
# ID: 101, Job: Software Test Engineer I
# ID: 102, Job: Analog Circuit Design manager
# ID: 103, Job: Project Manager
# ID: 104, Job: Occupational Therapist
# ID: 105, Job: Registered Nurse
# ID: 106, Job: Operator
# ID: 107, Job: Legal Assistant
# ID: 108, Job: Nurse
# ID: 109, Job: Technical Writer
# ID: 110, Job: Senior Sales Associate
# ID: 111, Job: Programmer I
# ID: 112, Job: Administrative Assistant I
# ID: 113, Job: Internal Auditor
# ID: 114, Job: Professor
# ID: 115, Job: Tax Accountant
# ID: 116, Job: Data Coordiator
# ID: 117, Job: Mechanical Systems Engineer
# ID: 118, Job: Web Developer II
# ID: 119, Job: Programmer Analyst IV
# ID: 120, Job: Editor
# ID: 121, Job: Web Developer III
# ID: 122, Job: Assistant Media Planner
# ID: 123, Job: Statistician I
# ID: 124, Job: Physical Therapy Assistant
# ID: 125, Job: Nurse Practicioner
# ID: 126, Job: Budget/Accounting Analyst II
# ID: 127, Job: Developer II
# ID: 128, Job: Budget/Accounting Analyst I
# ID: 129, Job: Accounting Assistant II
# ID: 130, Job: Programmer Analyst II
# ID: 131, Job: Help Desk Operator
# ID: 132, Job: Staff Accountant III
# ID: 133, Job: Computer Systems Analyst III
# ID: 134, Job: Developer III
# ID: 135, Job: Human Resources Manager
# ID: 136, Job: Payment Adjustment Coordinator
# ID: 137, Job: Account Representative III
# ID: 138, Job: Web Designer III
# ID: 139, Job: Database Administrator IV
# ID: 140, Job: Safety Technician I
# ID: 141, Job: Web Designer IV
# ID: 142, Job: Human Resources Assistant II
# ID: 143, Job: Health Coach I
# ID: 144, Job: Safety Technician II
# ID: 145, Job: Biostatistician II
# ID: 146, Job: Speech Pathologist
# ID: 147, Job: Design Engineer
# ID: 148, Job: Human Resources Assistant III
# ID: 149, Job: Safety Technician IV
# ID: 150, Job: Sales Associate
# ID: 151, Job: Accountant II
# ID: 152, Job: Developer I
# ID: 153, Job: Geologist I
# ID: 154, Job: Statistician III
# ID: 155, Job: Research Assistant III
# ID: 156, Job: Developer IV
# ID: 157, Job: Research Associate
# ID: 158, Job: Accounting Assistant I
# ID: 159, Job: Media Manager IV
# ID: 160, Job: Media Manager II
# ID: 161, Job: Software Test Engineer III
# ID: 162, Job: Compensation Analyst
# ID: 163, Job: Research Nurse
# ID: 164, Job: Administrative Assistant III
# ID: 165, Job: Computer Systems Analyst II
# ID: 166, Job: Accountant III
# ID: 167, Job: Administrative Assistant II
# ID: 168, Job: Staff Accountant II
# ID: 169, Job: Accounting Assistant III
# ID: 170, Job: Media Manager I
# ID: 171, Job: Safety Technician III
# ID: 172, Job: Engineer I
# ID: 173, Job: Research Assistant I
# ID: 174, Job: Software Engineer IV
# ID: 175, Job: Business Systems Development Analyst
# ID: 176, Job: Biostatistician I
# ID: 177, Job: Health Coach II
# ID: 178, Job: Staff Accountant I
# ID: 179, Job: Software Engineer II
# ID: 180, Job: Statistician IV
# ID: 181, Job: Programmer Analyst I
# ID: 182, Job: Account Representative I
# ID: 183, Job: Administrative Assistant IV

# %%
# Initialize Flask application
app = Flask(__name__)

template_folder = 'C:/Users/onico/OneDrive/Escritorio/Desafio/templates'
schemas = {
    'employees': ['id', 'name', 'datetime', 'department_id', 'job_id'],
    'departments': ['id', 'department'],
    'jobs': ['id', 'job']
}
tables = list(schemas.keys())
@app.route('/')
def index():
    return 'Welcome to my Flask application!'

# Menu for Backup and Restore features
#@app.route('/')
#def index():
#    return render_template('menu.html', tables=tables)

# Get table by name
def get_table_by_name(table_name):
    table = None
    if table_name == 'employees':
        table = employees
    elif table_name == 'departments':
        table = departments
    elif table_name == 'jobs':
        table = jobs
    return table

# Function to validate data dictionary rules
def validate_data(row, table_name):
    schema = schemas[table_name]
    skipped_reasons = []

    # Verify same number of fields
    if len(row) != len(schema):
        skipped_reasons.append(f"Number of columns doesn't match schema.")
        return None, skipped_reasons
                    
    # Verify all schema fields are in the row
    for campo in schema:
        if not row.get(campo):
            skipped_reasons.append(f"Missing field {campo}.")
            return None, skipped_reasons
    
    # Convert hire_datetime string to datetime object
    if 'datetime' in schema:
        try:
            row['datetime'] = parse_datetime(row['datetime'])
        except ValueError:
            skipped_reasons.append("Invalid datetime format.")
            return None, skipped_reasons

    # Validate numeric fields
    for campo in ['id', 'department_id', 'job_id']:
        if campo in schema:
            try:
                row[campo] = float(row[campo])
            except ValueError:
                skipped_reasons.append(f"Non-numeric value found in field {campo}.")
                return None, skipped_reasons

    return row, None


# REST API endpoint to receive new data
@app.route('/insert_data/<table_name>', methods=['POST'])
def insert_data(table_name):
    if table_name not in tables:
        return jsonify({'error': 'Table not found'}), 404

    data = request.json
    if not isinstance(data, list):
        return jsonify({'error': 'Data must be a list of dictionaries'}), 400

    valid_data = []
    skipped_data = {}

    for row in data:
        validated_row, skipped_reasons = validate_data(row, table_name)
        if validated_row:
            valid_data.append(validated_row)
        else:
            skipped_data[str(row)] = skipped_reasons

    if valid_data:
        table = get_table_by_name(table_name)

        try:
            with engine.begin() as conn:
                conn.execute(table.insert(), valid_data)
                conn.commit()  # Commit changes to the database
            return jsonify({'message': 'Data inserted successfully', 'skipped_rows': skipped_data}), 201
        except IntegrityError:
            return jsonify({'error': 'Integrity constraint violation'}), 400
    else:
        return jsonify({'error': 'All rows skipped', 'skipped_rows': skipped_data}), 400


# Backup feature
@app.route('/backup/<table_name>', methods=['POST'])
def backup_table(table_name):
    
    if table_name not in tables:
        return jsonify({'error': 'Table not found'}), 404

    data = request.json
    if not isinstance(data, dict):
        return jsonify({'error': 'Data must be a dictionary like {"name": "BackupName"}'}), 400

    backup_name = data.get('name')
    if not backup_name:
        return jsonify({'error': 'Missing or empty "name" field in the request body'}), 400
    
    if not isinstance(backup_name, str):
        return jsonify({'error': 'The value associated with the "name" field must be a string'}), 400
    
    table = get_table_by_name(table_name)

    if table is not None:
        # Get table metadata using SQLAlchemy's inspect function
        inspector = inspect(engine)
        columns = inspector.get_columns(table_name)

        # Generate AVRO schema based on table structure
        schema = {
            "type": "record",
            "name": table_name,
            "fields": [
                {"name": col['name'], "type": "string" if col['type'].python_type == str or col['type'].python_type == datetime.datetime else col['type'].python_type.__name__} for col in columns
            ]
        }

        # Retrieve data from the table
        results = session.query(table).all()

        # Convert SQLAlchemy results to list of dictionaries
        data = []
        for row in results:
            row_dict = {}
            for column in table.columns:
                # Convert datetime object to string
                if isinstance(getattr(row, column.name), datetime.datetime):
                    row_dict[column.name] = getattr(row, column.name).strftime('%Y-%m-%dT%H:%M:%SZ')
                else:
                    row_dict[column.name] = getattr(row, column.name)
            data.append(row_dict)

        # Specify the file path for the backup
        file_path = f'backup/{table_name}_{backup_name}_backup.avro'

        # Write data to AVRO file
        with open(file_path, 'wb') as f:
            fastavro.writer(f, schema, data)

        return jsonify({'message': f'Backup created successfully for table {table_name}', 'file_path': file_path}), 201
    else:
        return jsonify({'error': 'Table not found'}), 404


# Restore feature
@app.route('/restore/<table_name>', methods=['POST'])
def restore_table(table_name):
    if table_name not in tables:
        return jsonify({'error': 'Table not found'}), 404

    data = request.json
    if not isinstance(data, dict):
        return jsonify({'error': 'Data must be a dictionary like {"name": "BackupName"}'}), 400

    backup_name = data.get('name')
    if not backup_name:
        return jsonify({'error': 'Missing or empty "name" field in the request body'}), 400
    
    if not isinstance(backup_name, str):
        return jsonify({'error': 'The value associated with the "name" field must be a string'}), 400

    # Specify the file path for the backup
    file_path = f'backup/{table_name}_{backup_name}_backup.avro'

    try:
        with open(file_path, 'rb') as f:
            avro_reader = fastavro.reader(f)
            writer_schema = avro_reader.writer_schema

            # Read data from AVRO file into a list
            avro_data = list(avro_reader)

            # Validate schema against table schema
            table = get_table_by_name(table_name)
            
            expected_columns = [col['name'] for col in writer_schema['fields']]
            actual_columns = [col.name for col in table.columns]
            if expected_columns != actual_columns:
                return jsonify({'error': 'Failed to restore backup. Differences found in the schema of the backup and the table data.'}), 400

            # Convert datetime strings back to datetime objects
            if 'datetime' in expected_columns:
                for row in avro_data:
                    if 'datetime' in row:
                        row['datetime'] = parse_datetime(row['datetime'])
                            
            # Clear existing data in the table
            try:
                with engine.begin() as conn:
                    conn.execute(table.delete())
            except Exception as e:
                return jsonify({'error': f'Failed to restore backup. Could not delete the existing table. Error: {str(e)}'}), 400

            # Insert restored data into the table
            try:
                f.seek(0)
                with engine.begin() as conn:
                    conn.execute(table.insert(), avro_data)
                    conn.commit()  # Commit changes to the database
            except Exception as e:
                return jsonify({'error': f'Failed to restore backup. Could not load avro backup data to the existing table. Error: {str(e)}'}), 400

            return jsonify({'message': f'Data restored successfully for table {table_name} using the backup: {backup_name}'}), 200
    except FileNotFoundError:
        return jsonify({'error': f'Backup avro file not found in path {file_path}.'}), 404
    except Exception as e:
        return jsonify({'error': f'An error occurred while restoring backup: {str(e)}'}), 500


# Run App
if __name__ == '__main__':
    app.run(debug=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [27/Mar/2024 13:56:21] "POST /restore/employees HTTP/1.1" 200 -

# %% [markdown]
# ### Revisemos si se insertó la data

# %%
# Test loaded data with SQL
sql_query = text("SELECT * FROM employees WHERE id > 1995")
result = session.execute(sql_query)
resultados = result.fetchall()

# Print the rows
print("\nHired Employees:")
for r in resultados:
    row_data = " | ".join(f"{column}: {value}" for column, value in zip(result.keys(), r))
    print(row_data)
# Out:
# Hired Employees:
# id: 1996 | name: Cirstoforo Youings | datetime: 2021-04-01 17:48:42.000000 | department_id: 3 | job_id: 23
# id: 1997 | name: Wilek Yurkevich | datetime: 2021-05-04 12:19:50.000000 | department_id: 2 | job_id: 132
# id: 1998 | name: Jerry Yven | datetime: 2021-10-03 14:12:50.000000 | department_id: 7 | job_id: 100
# id: 1999 | name: Jerri Zebedee | datetime: 2022-01-18 10:47:37.000000 | department_id: 8 | job_id: 80
# id: 2011 | name: John Doe | datetime: 2024-03-26 12:00:00.000000 | department_id: 1 | job_id: 202
# id: 2012 | name: Jane Smith | datetime: 2024-03-26 13:00:00.000000 | department_id: 2 | job_id: 203
